# %% [markdown]
# # week 1

# %% [markdown]
# ### lab-dict-tups-sets

# %%
#Q: What does the f do in the print?
#A: Works as a text template

f"string and {variable}"
"string and {}".format(variable)

# %%
# PROBLEM:

letters = ["a", "b", "c", "d", "e"]
tup_3 = ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %%
# 1. What do I have
    # two iterables: tuple(strings) & list (strings)
    
# 2. What do I need to return
    # "strings" + number

# %%
# 1st approach - using for loops. Needs to be modified so that it counts more than one element
count = 0  
for i in letters:
    if i in tup_3:
        count+=1
    print (f"{i} appears {count} times")
# Out:
# a appears 2 times
# b appears 0 times
# c appears 1 times
# d appears 0 times
# e appears 0 times

# %%
# 2nd approach: .count() - David


#1. What we have: two things: one iterable(tuple) & another iterable (list)
tup3 = ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k', "a")
letters = ["a", "b", "c", "d", "e"]

#2. What we want to get/return: frequency of something
    #"for each element one iterable: how many times it happens in the other iterable"
    # 1. something (common elementas) & 2. number (how many times those elements happen)

lst_aux=[] #lst_aux=["a", "c"]


# c scenario
for i in letters:
    if i in tup3: #false, condition is not met
        lst_aux.append(i)
        print (f"{i} is True it's on the tuple tup3")
    else:
        print(f"instead {i} is not" )
        
print(lst_aux)

# lst_aux is a list with the common elements

# c
for j in lst_aux:
    if j in tup3:
        print(f"{j} is repeated", tup3.count(j), "times")
# Out:
# a is True it's on the tuple tup3
# instead b is not
# c is True it's on the tuple tup3
# instead d is not
# instead e is not
# ['a', 'c']

# %%
# 3rd approach: 

dict_ = {
    "a": 0,
    "b": 0,
    "c": 0,
    "d": 0,
    "e": 0
}

# 1. Create a dictionary the keys being the set of one iterable: `letters`
# 2. Each value: 0
# 3. Add as I find more

# %%
# 1. Dictionary set to zeros
for i in letters: 
    dict_[i] = 0 # -> "a": 0
print(dict_)


# 2. Change the zeros: adding every time it encounters it


# 1st scenario: "I"
for i in tup_3:
    if i in dict_.keys(): #True
        dict_[i] += 1 #modify pair key:value
dict_
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0}

# %%
len(set3)+len(set5)-len(set1) == len(set5)+len(set4)-len(set2)
                            #0 == 0

# %% [markdown]
# ![8a86759a8833123526f0aed16a486ba5.jpg](attachment:8a86759a8833123526f0aed16a486ba5.jpg)
