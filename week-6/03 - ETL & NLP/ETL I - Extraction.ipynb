# %% [markdown]
# # <center>📦🧹🔍ETL 🔍🧹📦<center>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#What-does-ETL-stand-for?" data-toc-modified-id="What-does-ETL-stand-for?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>What does ETL stand for?</a></span></li><li><span><a href="#What-are-we-going-to-do?" data-toc-modified-id="What-are-we-going-to-do?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What are we going to do?</a></span></li><li><span><a href="#We-import-libraries" data-toc-modified-id="We-import-libraries-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>We import libraries</a></span></li><li><span><a href="#Mission-1:-Obtain-the-Spotify-token-to-use-its-API-🗝" data-toc-modified-id="Mission-1:-Obtain-the-Spotify-token-to-use-its-API-🗝-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Mission 1: Obtain the Spotify token to use its API 🗝</a></span></li><li><span><a href="#Spotify-token" data-toc-modified-id="Spotify-token-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Spotify token</a></span></li><li><span><a href="#We-save-the-token-in-our-.env" data-toc-modified-id="We-save-the-token-in-our-.env-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>We save the token in our .env</a></span></li><li><span><a href="#📚-Recap-so-far:" data-toc-modified-id="📚-Recap-so-far:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>📚 Recap so far:</a></span></li><li><span><a href="#Mission-2:-Get-the-list-of-songs-and-artists-from-the-Spotify-API-🔥" data-toc-modified-id="Mission-2:-Get-the-list-of-songs-and-artists-from-the-Spotify-API-🔥-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Mission 2: Get the list of songs and artists from the Spotify API 🔥</a></span><ul class="toc-item"><li><span><a href="#Spotify-API-call" data-toc-modified-id="Spotify-API-call-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Spotify API call</a></span><ul class="toc-item"><li><span><a href="#We-need-token-and-headers" data-toc-modified-id="We-need-token-and-headers-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>We need token and headers</a></span></li><li><span><a href="#Url-+-endpoint" data-toc-modified-id="Url-+-endpoint-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Url + endpoint</a></span></li><li><span><a href="#We-make-the-request" data-toc-modified-id="We-make-the-request-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>We make the request</a></span></li><li><span><a href="#Function-to-extract-info-from-dictionaries" data-toc-modified-id="Function-to-extract-info-from-dictionaries-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>Function to extract info from dictionaries</a></span></li></ul></li><li><span><a href="#We're-taking-it-to-Pandas!-🐼" data-toc-modified-id="We're-taking-it-to-Pandas!-🐼-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>We're taking it to Pandas! 🐼</a></span></li></ul></li><li><span><a href="#Mission-3:-Get-song-lyrics" data-toc-modified-id="Mission-3:-Get-song-lyrics-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Mission 3: Get song lyrics</a></span><ul class="toc-item"><li><span><a href="#store-it-in-a-variable" data-toc-modified-id="store-it-in-a-variable-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>store it in a variable</a></span></li><li><span><a href="#We-are-looking-for-some-lyrics" data-toc-modified-id="We-are-looking-for-some-lyrics-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>We are looking for some lyrics</a></span></li><li><span><a href="#Many-lyrics!" data-toc-modified-id="Many-lyrics!-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Many lyrics!</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![data](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy.gif)

# %% [markdown]
# # Process to follow during the 3 jupyter notebook
# **Jupyter ETL I - Extraction and transformation**
#
# * I get spotify token
# * I make request to the API:
#     - Be careful if the lists have more than 100 songs
#     - Functions that automate the process
# * I get the lyrics of the songs (enrichment) with another library
#
# **Jupyter ETL II - Loading**
#
# * I connect with the databases
# * I create my schema in MySQL
# * I clean the data a bit
# * Check functions before putting my data in the database
# * I load my data to MySQL
# * I export json to load it in MongoDB
#
# **Jupyter NLP**
# * I get the data I want from the databases
# * Tokenize and remove stop words
# * I do Sentiment Analysis with the libraries
# * draw conclusions

# %% [markdown]
# ## What does ETL stand for?
# **Extract**, **Transform** and **Load** is the process that enables organizations to move data from multiple sources, reformat and cleanse it, and load it into another database, data mart, or data warehouse to analyze, or in another operational system to support a business process.

# %% [markdown]
# ## What are we going to do?
# - Learn to use the Spotify API with Oauth
# - Extract data from said API
# - Clean and transform them
# - Enrich them
# - Save them in different databases
# - Make queries to do sentiment analysis with NLP libraries

# %% [markdown]
# ## We import libraries

# %%
import os

import json
import requests
import pyjsonviewer

from functools import reduce
import operator

import pandas as pd
import numpy as np

import lyricsgenius
from lyrics_extractor import SongLyrics

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X?si=4865e6ee629d488b&pt=0ae09e3cb50938ee8f2fc768c208c1c2

# %% [markdown]
# ## Mission 1: Obtain the Spotify token to use its API 🗝

# %% [markdown]
# ## Spotify token
# https://developer.spotify.com/dashboard/login
# We need to have the CLIENT_ID and SECRET_ID tokens, and we store them in the `.env`.
#
#
# 1. Sign up as a devloper
# 2. Create an APP/project on spotify
# 3. Get client_id & client_secret
#
# To call the spotify api and get the token that will allow us to make a request, we are going to have to save a few variables.
# Read the [Documentation](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %%
# 1. Auth for app
    # CLIENT_ID
    # CLIENT_SECRET

# 2. Auth for queries    
    # token

# %%
# demo-scraping: send

# result: what I get

# %%
body_params = {"grant_type":"client_credentials"}

url = "https://accounts.spotify.com/api/token"

# %%
response = requests.post(url, data=body_params, auth=(CLIENT_ID,CLIENT_SECRET))

# %%
token = response.json()["access_token"]

# %%
#access_token
#authorization: bearer
#expiration:3600

# %% [markdown]
# We are going to write all this in a function because, as we have seen, the token expires and so we can call it whenever we want and reuse it. This is what functions are for!

# %%
# I need to hide my credentials: .env

# %%
def spotifyToken ():
    
    """This function refreshes a token for a given app on Spotify
    returns: token as a string
    """

    # 1. Defining: credentials fot the app
    
    CLIENT_ID = os.getenv("CLIENT_ID")
    CLIENT_SECRET = os.getenv("CLIENT_SECRET")
    
    #2. Request
    
    body_params = {"grant_type":"client_credentials"}
    url = "https://accounts.spotify.com/api/token"
    response = requests.post(url, data=body_params, auth=(CLIENT_ID,CLIENT_SECRET))
    
    try:
        token = response.json()["access_token"]
        return token

    except:
        print("The request did not go through: wrong credentials?")

# %%
token = spotifyToken ()

# %% [markdown]
# ## We save the token in our .env

# %%
# 1. Crearte .env
# 2. Input the variables

# %%
import os 
os.system(variable)

# %%
def save_token (CLIENT_ID, CLIENT_SECRET):
    command = f"""echo "CLIENT_ID='{CLIENT_ID}'\nCLIENT_SECRET='{CLIENT_SECRET}'" > .env"""
    os.system(command)

# %% [markdown]
# We make a function that does the same thing to be able to reuse it

# %% [markdown]
# ## 📚 Recap so far:
#
# **What we have done**
# - 1. We get our Spotify authentication
# - 2. With that, we get our spotify `token`: issuing a request.post
# - 3. We save the `token` in the .env <br>
# <br>
#
# **To remember**
#
# - **CLIENT_ID** & **CLIENT_SECRET** is just a means to get the `token`, not the authentication itself.
# - The `token` expires

# %% [markdown]
# ## Mission 2: Get the list of songs and artists from the Spotify API 🔥
# But let's not forget about the [documentation](https://developer.spotify.com/console/)
# The first thing we are going to do is make an API call
# Let's remember the syntax:
#
# `request.get(url, headers)`

# %% [markdown]
# ### Spotify API call

# %% [markdown]
# #### We need token and headers

# %%
#token
headers = {"Authorization":f"Bearer {token}"}

# %% [markdown]
# We take the ID of the list of the share link that comes out in spotify (Link of the song)
# https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X?si=838e81628a2e4a23

# %%
url_base = "https://api.spotify.com/v1/playlists/"

# %% [markdown]
# The ID of the list from which we want to make the request

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DWTf6wqAsYxqz?si=df69ba9e488249b5"

# %%
playlist_id = playlist_link.split("/")[-1].split("?")[0]
playlist_id
# Out:
# '37i9dQZF1DWTf6wqAsYxqz'

# %%
playlist_link_2 = "https://open.spotify.com/playlist/50v0ITLYuxui3QRwd0CNTW?si=3176623842434386"
playlist_id_2 = "50v0ITLYuxui3QRwd0CNTW"
query_2 = url_base + playlist_id_2
response_2 = requests.get(query_2, headers=headers).json()
response_2
# Out:
# {'collaborative': True,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/50v0ITLYuxui3QRwd0CNTW'},
#  'followers': {'href': None, 'total': 5},
#  'href': 'https://api.spotify.com/v1/playlists/50v0ITLYuxui3QRwd0CNTW',
#  'id': '50v0ITLYuxui3QRwd0CNTW',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b273379540c86420ea590936e25eab67616d0000b2737d57ac4e84d2c826094f9890ab67616d0000b273a00ebf57f89f4202d299976bab67616d0000b273cc4fe4fda4dd75b123f64b20',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b273379540c86420ea590936e25eab67616d0000b2737d57ac4e84d2c826094f9890ab67616d0000b273a00ebf57f89f4202d299976bab67616d0000b273cc4fe4fda4dd75b123f64b20',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b273379540c86420ea590936e25eab67616d0000b2737d57ac4e84d2c826094f9890ab67616d0000b273a00ebf57f89f4202d299976bab67616d0000b273cc4fe4fda4dd75b123f64b20',
#    'width': 60}],
#  'name': 'Caracas 450',
#  'owner': {'display_name': 'soyarepita',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#   'href': 'https://api.spotify.com/v1/users/soyarepita',
#   'id': 'soyarepita',
#   'type': 'user',
#   'uri': 'spotify:user:soyarepita'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'MzksNWFjY2I3NmZmZTNkM2NiMWU0ZTliNjhjOWM3ZTQxMDcwYzUxZWYyYQ==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/50v0ITLYuxui3QRwd0CNTW/tracks?offset=0&limit=100',
#   'items': [{'added_at': '2017-07-27T22:50:57Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#         'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#         'id': '38zyliF0xdJKS7k1BIEuL6',
#         'name': "Billo's",
#         'type': 'artist',
#         'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1ULbLQSkAyLDWONzJBEsVY'},
#       'href': 'https://api.spotify.com/v1/albums/1ULbLQSkAyLDWONzJBEsVY',
#       'id': '1ULbLQSkAyLDWONzJBEsVY',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734b8a48868d7a3a85e5e025f1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024b8a48868d7a3a85e5e025f1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514b8a48868d7a3a85e5e025f1',
#         'width': 64}],
#       'name': 'Canto a Caracas',
#       'release_date': '1972-09-10',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:1ULbLQSkAyLDWONzJBEsVY'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#        'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#        'id': '38zyliF0xdJKS7k1BIEuL6',
#        'name': "Billo's",
#        'type': 'artist',
#        'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 151719,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMFMG1535243'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4owMy9cNUKbq66dreAiA9k'},
#      'href': 'https://api.spotify.com/v1/tracks/4owMy9cNUKbq66dreAiA9k',
#      'id': '4owMy9cNUKbq66dreAiA9k',
#      'is_local': False,
#      'name': 'Canto a Caracas',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4owMy9cNUKbq66dreAiA9k'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T04:14:36Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kyQwKHCZnKE7kTXkxXjrB'},
#         'href': 'https://api.spotify.com/v1/artists/0kyQwKHCZnKE7kTXkxXjrB',
#         'id': '0kyQwKHCZnKE7kTXkxXjrB',
#         'name': 'Desorden Público',
#         'type': 'artist',
#         'uri': 'spotify:artist:0kyQwKHCZnKE7kTXkxXjrB'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3nJ96aVnAwpdykZcS5L6uZ'},
#       'href': 'https://api.spotify.com/v1/albums/3nJ96aVnAwpdykZcS5L6uZ',
#       'id': '3nJ96aVnAwpdykZcS5L6uZ',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2737d57ac4e84d2c826094f9890',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e027d57ac4e84d2c826094f9890',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048517d57ac4e84d2c826094f9890',
#         'width': 64}],
#       'name': 'Descomposición',
#       'release_date': '2015-11-20',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:3nJ96aVnAwpdykZcS5L6uZ'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kyQwKHCZnKE7kTXkxXjrB'},
#        'href': 'https://api.spotify.com/v1/artists/0kyQwKHCZnKE7kTXkxXjrB',
#        'id': '0kyQwKHCZnKE7kTXkxXjrB',
#        'name': 'Desorden Público',
#        'type': 'artist',
#        'uri': 'spotify:artist:0kyQwKHCZnKE7kTXkxXjrB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 228840,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'VES019000015'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/16VdR8gjzgVvaj8B0Fnuu2'},
#      'href': 'https://api.spotify.com/v1/tracks/16VdR8gjzgVvaj8B0Fnuu2',
#      'id': '16VdR8gjzgVvaj8B0Fnuu2',
#      'is_local': False,
#      'name': 'Peces del Guaire',
#      'popularity': 3,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e1b7266b2040316ccb818c105888bbafe149ec43?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:16VdR8gjzgVvaj8B0Fnuu2'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T04:25:59Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0LZ28xnsor2Oo4SO3fh0FO'},
#       'href': 'https://api.spotify.com/v1/albums/0LZ28xnsor2Oo4SO3fh0FO',
#       'id': '0LZ28xnsor2Oo4SO3fh0FO',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273b7d6b5a3f5de70bdf48fb455',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02b7d6b5a3f5de70bdf48fb455',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851b7d6b5a3f5de70bdf48fb455',
#         'width': 64}],
#       'name': 'El Comienzo en un Sotano de la Florida',
#       'release_date': '1987-08-28',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:0LZ28xnsor2Oo4SO3fh0FO'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hLPLpgj8orEpTrNyPvkn8'},
#        'href': 'https://api.spotify.com/v1/artists/5hLPLpgj8orEpTrNyPvkn8',
#        'id': '5hLPLpgj8orEpTrNyPvkn8',
#        'name': 'Ilan Chester',
#        'type': 'artist',
#        'uri': 'spotify:artist:5hLPLpgj8orEpTrNyPvkn8'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 169586,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMFMG1521070'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2NWNYDkBkoenxkMWyggbt0'},
#      'href': 'https://api.spotify.com/v1/tracks/2NWNYDkBkoenxkMWyggbt0',
#      'id': '2NWNYDkBkoenxkMWyggbt0',
#      'is_local': False,
#      'name': 'Cerro Avila',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2NWNYDkBkoenxkMWyggbt0'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T13:30:13Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/marianamartinh'},
#      'href': 'https://api.spotify.com/v1/users/marianamartinh',
#      'id': 'marianamartinh',
#      'type': 'user',
#      'uri': 'spotify:user:marianamartinh'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kyQwKHCZnKE7kTXkxXjrB'},
#         'href': 'https://api.spotify.com/v1/artists/0kyQwKHCZnKE7kTXkxXjrB',
#         'id': '0kyQwKHCZnKE7kTXkxXjrB',
#         'name': 'Desorden Público',
#         'type': 'artist',
#         'uri': 'spotify:artist:0kyQwKHCZnKE7kTXkxXjrB'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5LIVxzLRdrJowxmLayI3uc'},
#       'href': 'https://api.spotify.com/v1/albums/5LIVxzLRdrJowxmLayI3uc',
#       'id': '5LIVxzLRdrJowxmLayI3uc',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273cc4fe4fda4dd75b123f64b20',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02cc4fe4fda4dd75b123f64b20',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851cc4fe4fda4dd75b123f64b20',
#         'width': 64}],
#       'name': 'Plomo Revienta',
#       'release_date': '1997',
#       'release_date_precision': 'year',
#       'total_tracks': 17,
#       'type': 'album',
#       'uri': 'spotify:album:5LIVxzLRdrJowxmLayI3uc'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kyQwKHCZnKE7kTXkxXjrB'},
#        'href': 'https://api.spotify.com/v1/artists/0kyQwKHCZnKE7kTXkxXjrB',
#        'id': '0kyQwKHCZnKE7kTXkxXjrB',
#        'name': 'Desorden Público',
#        'type': 'artist',
#        'uri': 'spotify:artist:0kyQwKHCZnKE7kTXkxXjrB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 159160,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'VES019700049'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0P7nIPKtiTaKFlYnRqTVpY'},
#      'href': 'https://api.spotify.com/v1/tracks/0P7nIPKtiTaKFlYnRqTVpY',
#      'id': '0P7nIPKtiTaKFlYnRqTVpY',
#      'is_local': False,
#      'name': 'Valle De Balas',
#      'popularity': 22,
#      'preview_url': 'https://p.scdn.co/mp3-preview/29f848dacaf59df7a91ec4c49a390c5b03591101?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:0P7nIPKtiTaKFlYnRqTVpY'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-27T22:54:57Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v3TYN6Mmi5vxV2uSOfXot'},
#         'href': 'https://api.spotify.com/v1/artists/5v3TYN6Mmi5vxV2uSOfXot',
#         'id': '5v3TYN6Mmi5vxV2uSOfXot',
#         'name': 'Guaco',
#         'type': 'artist',
#         'uri': 'spotify:artist:5v3TYN6Mmi5vxV2uSOfXot'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4irR3HfqLTMhKNsr42R06c'},
#       'href': 'https://api.spotify.com/v1/albums/4irR3HfqLTMhKNsr42R06c',
#       'id': '4irR3HfqLTMhKNsr42R06c',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a00ebf57f89f4202d299976b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a00ebf57f89f4202d299976b',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a00ebf57f89f4202d299976b',
#         'width': 64}],
#       'name': 'Guaco Es Guaco',
#       'release_date': '2016-11-04',
#       'release_date_precision': 'day',
#       'total_tracks': 14,
#       'type': 'album',
#       'uri': 'spotify:album:4irR3HfqLTMhKNsr42R06c'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v3TYN6Mmi5vxV2uSOfXot'},
#        'href': 'https://api.spotify.com/v1/artists/5v3TYN6Mmi5vxV2uSOfXot',
#        'id': '5v3TYN6Mmi5vxV2uSOfXot',
#        'name': 'Guaco',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v3TYN6Mmi5vxV2uSOfXot'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 233706,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USJE61611081'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0B5pOLlr0OLEVdE0PBG8pF'},
#      'href': 'https://api.spotify.com/v1/tracks/0B5pOLlr0OLEVdE0PBG8pF',
#      'id': '0B5pOLlr0OLEVdE0PBG8pF',
#      'is_local': False,
#      'name': 'Las Caraqueñas',
#      'popularity': 29,
#      'preview_url': 'https://p.scdn.co/mp3-preview/5c0a87ccaab6524b38b80ff260846800bec7a325?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0B5pOLlr0OLEVdE0PBG8pF'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-27T22:50:57Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#         'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#         'id': '38zyliF0xdJKS7k1BIEuL6',
#         'name': "Billo's",
#         'type': 'artist',
#         'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1ULbLQSkAyLDWONzJBEsVY'},
#       'href': 'https://api.spotify.com/v1/albums/1ULbLQSkAyLDWONzJBEsVY',
#       'id': '1ULbLQSkAyLDWONzJBEsVY',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734b8a48868d7a3a85e5e025f1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024b8a48868d7a3a85e5e025f1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514b8a48868d7a3a85e5e025f1',
#         'width': 64}],
#       'name': 'Canto a Caracas',
#       'release_date': '1972-09-10',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:1ULbLQSkAyLDWONzJBEsVY'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#        'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#        'id': '38zyliF0xdJKS7k1BIEuL6',
#        'name': "Billo's",
#        'type': 'artist',
#        'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 114991,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMFMG1535248'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1ogOr8DH8sdCGgAtcUZoGS'},
#      'href': 'https://api.spotify.com/v1/tracks/1ogOr8DH8sdCGgAtcUZoGS',
#      'id': '1ogOr8DH8sdCGgAtcUZoGS',
#      'is_local': False,
#      'name': 'Epa Isidoro',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:1ogOr8DH8sdCGgAtcUZoGS'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T13:48:58Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1253681944'},
#      'href': 'https://api.spotify.com/v1/users/1253681944',
#      'id': '1253681944',
#      'type': 'user',
#      'uri': 'spotify:user:1253681944'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mq5Rgvn4D37tQdwuFL689'},
#         'href': 'https://api.spotify.com/v1/artists/1Mq5Rgvn4D37tQdwuFL689',
#         'id': '1Mq5Rgvn4D37tQdwuFL689',
#         'name': 'Justo Betancourt',
#         'type': 'artist',
#         'uri': 'spotify:artist:1Mq5Rgvn4D37tQdwuFL689'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7Hi3Xst5cdbaaAqpNm5vgC'},
#       'href': 'https://api.spotify.com/v1/albums/7Hi3Xst5cdbaaAqpNm5vgC',
#       'id': '7Hi3Xst5cdbaaAqpNm5vgC',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732da4fb4c8a5d1a88c532e37a',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022da4fb4c8a5d1a88c532e37a',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512da4fb4c8a5d1a88c532e37a',
#         'width': 64}],
#       'name': 'Pa Bravo Yo',
#       'release_date': '2009',
#       'release_date_precision': 'year',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:7Hi3Xst5cdbaaAqpNm5vgC'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mq5Rgvn4D37tQdwuFL689'},
#        'href': 'https://api.spotify.com/v1/artists/1Mq5Rgvn4D37tQdwuFL689',
#        'id': '1Mq5Rgvn4D37tQdwuFL689',
#        'name': 'Justo Betancourt',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Mq5Rgvn4D37tQdwuFL689'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 185546,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USDBB0604666'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0PwxfDGkv3NoBDP0weZz7Q'},
#      'href': 'https://api.spotify.com/v1/tracks/0PwxfDGkv3NoBDP0weZz7Q',
#      'id': '0PwxfDGkv3NoBDP0weZz7Q',
#      'is_local': False,
#      'name': 'Caracas Tiene Su Guaguanco',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0PwxfDGkv3NoBDP0weZz7Q'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-27T22:50:57Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#         'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#         'id': '38zyliF0xdJKS7k1BIEuL6',
#         'name': "Billo's",
#         'type': 'artist',
#         'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1ULbLQSkAyLDWONzJBEsVY'},
#       'href': 'https://api.spotify.com/v1/albums/1ULbLQSkAyLDWONzJBEsVY',
#       'id': '1ULbLQSkAyLDWONzJBEsVY',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734b8a48868d7a3a85e5e025f1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024b8a48868d7a3a85e5e025f1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514b8a48868d7a3a85e5e025f1',
#         'width': 64}],
#       'name': 'Canto a Caracas',
#       'release_date': '1972-09-10',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:1ULbLQSkAyLDWONzJBEsVY'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38zyliF0xdJKS7k1BIEuL6'},
#        'href': 'https://api.spotify.com/v1/artists/38zyliF0xdJKS7k1BIEuL6',
#        'id': '38zyliF0xdJKS7k1BIEuL6',
#        'name': "Billo's",
#        'type': 'artist',
#        'uri': 'spotify:artist:38zyliF0xdJKS7k1BIEuL6'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 182857,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMFMG1535250'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6f52SYT2XpNfL7XRvZWLXE'},
#      'href': 'https://api.spotify.com/v1/tracks/6f52SYT2XpNfL7XRvZWLXE',
#      'id': '6f52SYT2XpNfL7XRvZWLXE',
#      'is_local': False,
#      'name': 'Luna Caraqueña',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:6f52SYT2XpNfL7XRvZWLXE'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-27T22:51:12Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyarepita'},
#      'href': 'https://api.spotify.com/v1/users/soyarepita',
#      'id': 'soyarepita',
#      'type': 'user',
#      'uri': 'spotify:user:soyarepita'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kavuvnHTeqwjKLV7qPpQm'},
#         'href': 'https://api.spotify.com/v1/artists/0kavuvnHTeqwjKLV7qPpQm',
#         'id': '0kavuvnHTeqwjKLV7qPpQm',
#         'name': 'Piero',
#         'type': 'artist',
#         'uri': 'spotify:artist:0kavuvnHTeqwjKLV7qPpQm'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6aJJoucuAoeXCKNIwHz16K'},
#       'href': 'https://api.spotify.com/v1/albums/6aJJoucuAoeXCKNIwHz16K',
#       'id': '6aJJoucuAoeXCKNIwHz16K',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731688065eb9618188906c7682',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021688065eb9618188906c7682',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511688065eb9618188906c7682',
#         'width': 64}],
#       'name': 'Piero',
#       'release_date': '1975-03-18',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:6aJJoucuAoeXCKNIwHz16K'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kavuvnHTeqwjKLV7qPpQm'},
#        'href': 'https://api.spotify.com/v1/artists/0kavuvnHTeqwjKLV7qPpQm',
#        'id': '0kavuvnHTeqwjKLV7qPpQm',
#        'name': 'Piero',
#        'type': 'artist',
#        'uri': 'spotify:artist:0kavuvnHTeqwjKLV7qPpQm'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 142933,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QM4TW1787185'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3dsqF9OnNz5QeCEsKww5bM'},
#      'href': 'https://api.spotify.com/v1/tracks/3dsqF9OnNz5QeCEsKww5bM',
#      'id': '3dsqF9OnNz5QeCEsKww5bM',
#      'is_local': False,
#      'name': 'Caminando por Caracas',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:3dsqF9OnNz5QeCEsKww5bM'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T13:51:36Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1253681944'},
#      'href': 'https://api.spotify.com/v1/users/1253681944',
#      'id': '1253681944',
#      'type': 'user',
#      'uri': 'spotify:user:1253681944'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xZFfvN3tRXsmgPGEwyuME'},
#         'href': 'https://api.spotify.com/v1/artists/6xZFfvN3tRXsmgPGEwyuME',
#         'id': '6xZFfvN3tRXsmgPGEwyuME',
#         'name': 'Javith',
#         'type': 'artist',
#         'uri': 'spotify:artist:6xZFfvN3tRXsmgPGEwyuME'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/626WN0fCtQGKTVU2V8ZMqA'},
#       'href': 'https://api.spotify.com/v1/albums/626WN0fCtQGKTVU2V8ZMqA',
#       'id': '626WN0fCtQGKTVU2V8ZMqA',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2733daccd556e747e4aa7bc6618',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e023daccd556e747e4aa7bc6618',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048513daccd556e747e4aa7bc6618',
#         'width': 64}],
#       'name': 'Caracas de Noche (Remixes)',
#       'release_date': '2015-09-28',
#       'release_date_precision': 'day',
#       'total_tracks': 9,
#       'type': 'album',
#       'uri': 'spotify:album:626WN0fCtQGKTVU2V8ZMqA'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xZFfvN3tRXsmgPGEwyuME'},
#        'href': 'https://api.spotify.com/v1/artists/6xZFfvN3tRXsmgPGEwyuME',
#        'id': '6xZFfvN3tRXsmgPGEwyuME',
#        'name': 'Javith',
#        'type': 'artist',
#        'uri': 'spotify:artist:6xZFfvN3tRXsmgPGEwyuME'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1lsFzi42MyFb3Z3vYyiDrH'},
#        'href': 'https://api.spotify.com/v1/artists/1lsFzi42MyFb3Z3vYyiDrH',
#        'id': '1lsFzi42MyFb3Z3vYyiDrH',
#        'name': 'Marvin DJ',
#        'type': 'artist',
#        'uri': 'spotify:artist:1lsFzi42MyFb3Z3vYyiDrH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XC',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 364564,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMHUY1556263'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4HLAYujCZoxqosFs86AiTc'},
#      'href': 'https://api.spotify.com/v1/tracks/4HLAYujCZoxqosFs86AiTc',
#      'id': '4HLAYujCZoxqosFs86AiTc',
#      'is_local': False,
#      'name': 'Caracas de Noche - Original Mix',
#      'popularity': 26,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dc0ea06502d0ed017f99c32535ed125bd9c6495e?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:4HLAYujCZoxqosFs86AiTc'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T13:53:03Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1253681944'},
#      'href': 'https://api.spotify.com/v1/users/1253681944',
#      'id': '1253681944',
#      'type': 'user',
#      'uri': 'spotify:user:1253681944'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qZ2nd2D7X0lQs22nwm4Gx'},
#         'href': 'https://api.spotify.com/v1/artists/7qZ2nd2D7X0lQs22nwm4Gx',
#         'id': '7qZ2nd2D7X0lQs22nwm4Gx',
#         'name': 'Medioevo',
#         'type': 'artist',
#         'uri': 'spotify:artist:7qZ2nd2D7X0lQs22nwm4Gx'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/56od7FmqT1GJvlnVsEl0M2'},
#       'href': 'https://api.spotify.com/v1/albums/56od7FmqT1GJvlnVsEl0M2',
#       'id': '56od7FmqT1GJvlnVsEl0M2',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273de273a95c9a8c43fe963a6ca',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02de273a95c9a8c43fe963a6ca',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851de273a95c9a8c43fe963a6ca',
#         'width': 64}],
#       'name': 'La Sifrina',
#       'release_date': '2016-04-04',
#       'release_date_precision': 'day',
#       'total_tracks': 14,
#       'type': 'album',
#       'uri': 'spotify:album:56od7FmqT1GJvlnVsEl0M2'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qZ2nd2D7X0lQs22nwm4Gx'},
#        'href': 'https://api.spotify.com/v1/artists/7qZ2nd2D7X0lQs22nwm4Gx',
#        'id': '7qZ2nd2D7X0lQs22nwm4Gx',
#        'name': 'Medioevo',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qZ2nd2D7X0lQs22nwm4Gx'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 277403,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMDA71592973'},
# ...
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3EO1GDw12fSeUFUy5L1lVN'},
#       'href': 'https://api.spotify.com/v1/albums/3EO1GDw12fSeUFUy5L1lVN',
#       'id': '3EO1GDw12fSeUFUy5L1lVN',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27382e78dfe7836329cfccb2b06',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0282e78dfe7836329cfccb2b06',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485182e78dfe7836329cfccb2b06',
#         'width': 64}],
#       'name': 'Colores de Ideas #7',
#       'release_date': '2010-01-02',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:3EO1GDw12fSeUFUy5L1lVN'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gnuMMiUlRWdlMZ37kNfun'},
#        'href': 'https://api.spotify.com/v1/artists/2gnuMMiUlRWdlMZ37kNfun',
#        'id': '2gnuMMiUlRWdlMZ37kNfun',
#        'name': 'Masseratti 2Lts',
#        'type': 'artist',
#        'uri': 'spotify:artist:2gnuMMiUlRWdlMZ37kNfun'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XC',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 229000,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'usx9p0971999'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5H2aTlYirPMhgdbzYyvNOm'},
#      'href': 'https://api.spotify.com/v1/tracks/5H2aTlYirPMhgdbzYyvNOm',
#      'id': '5H2aTlYirPMhgdbzYyvNOm',
#      'is_local': False,
#      'name': 'Caracas: Te Quiero _ _ _ _ _',
#      'popularity': 13,
#      'preview_url': 'https://p.scdn.co/mp3-preview/cc42922f3072a5b27738f9d8948d1b47d871263a?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:5H2aTlYirPMhgdbzYyvNOm'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T18:28:06Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1245001868'},
#      'href': 'https://api.spotify.com/v1/users/1245001868',
#      'id': '1245001868',
#      'type': 'user',
#      'uri': 'spotify:user:1245001868'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53cMuUeUaSssllBefE5RRt'},
#         'href': 'https://api.spotify.com/v1/artists/53cMuUeUaSssllBefE5RRt',
#         'id': '53cMuUeUaSssllBefE5RRt',
#         'name': 'Telegrama',
#         'type': 'artist',
#         'uri': 'spotify:artist:53cMuUeUaSssllBefE5RRt'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7zrkMgsg5KEGFF6Uiksf2s'},
#       'href': 'https://api.spotify.com/v1/albums/7zrkMgsg5KEGFF6Uiksf2s',
#       'id': '7zrkMgsg5KEGFF6Uiksf2s',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731522203fb1c3f1c995aed726',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021522203fb1c3f1c995aed726',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511522203fb1c3f1c995aed726',
#         'width': 64}],
#       'name': 'Cambia Tus Amigos',
#       'release_date': '2013-05-27',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:7zrkMgsg5KEGFF6Uiksf2s'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53cMuUeUaSssllBefE5RRt'},
#        'href': 'https://api.spotify.com/v1/artists/53cMuUeUaSssllBefE5RRt',
#        'id': '53cMuUeUaSssllBefE5RRt',
#        'name': 'Telegrama',
#        'type': 'artist',
#        'uri': 'spotify:artist:53cMuUeUaSssllBefE5RRt'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 290960,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'ESA011303897'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1UdeJXKFN5DS9GYscfae69'},
#      'href': 'https://api.spotify.com/v1/tracks/1UdeJXKFN5DS9GYscfae69',
#      'id': '1UdeJXKFN5DS9GYscfae69',
#      'is_local': False,
#      'name': 'La Hora De Caracas',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:1UdeJXKFN5DS9GYscfae69'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-07-28T21:01:11Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/marianamartinh'},
#      'href': 'https://api.spotify.com/v1/users/marianamartinh',
#      'id': 'marianamartinh',
#      'type': 'user',
#      'uri': 'spotify:user:marianamartinh'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7An4yvF7hDYDolN4m5zKBp'},
#         'href': 'https://api.spotify.com/v1/artists/7An4yvF7hDYDolN4m5zKBp',
#         'id': '7An4yvF7hDYDolN4m5zKBp',
#         'name': 'Soda Stereo',
#         'type': 'artist',
#         'uri': 'spotify:artist:7An4yvF7hDYDolN4m5zKBp'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0IkprxBZTCQhSry1AsDxcb'},
#       'href': 'https://api.spotify.com/v1/albums/0IkprxBZTCQhSry1AsDxcb',
#       'id': '0IkprxBZTCQhSry1AsDxcb',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273b49b1b486de0d62e8b4cade3',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02b49b1b486de0d62e8b4cade3',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851b49b1b486de0d62e8b4cade3',
#         'width': 64}],
#       'name': 'Me Verás Volver (Hits & Más)',
#       'release_date': '2007-06-28',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:0IkprxBZTCQhSry1AsDxcb'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7An4yvF7hDYDolN4m5zKBp'},
#        'href': 'https://api.spotify.com/v1/artists/7An4yvF7hDYDolN4m5zKBp',
#        'id': '7An4yvF7hDYDolN4m5zKBp',
#        'name': 'Soda Stereo',
#        'type': 'artist',
#        'uri': 'spotify:artist:7An4yvF7hDYDolN4m5zKBp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 344893,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'ARFSB0700917'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0FgyQCIP54DL9nieiQx35P'},
#      'href': 'https://api.spotify.com/v1/tracks/0FgyQCIP54DL9nieiQx35P',
#      'id': '0FgyQCIP54DL9nieiQx35P',
#      'is_local': False,
#      'name': 'En La Ciudad De La Furia - Remasterizado 2007',
#      'popularity': 50,
#      'preview_url': 'https://p.scdn.co/mp3-preview/b9eec24d32a7d0e088f9b747008ff08798408634?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:0FgyQCIP54DL9nieiQx35P'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 15},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:50v0ITLYuxui3QRwd0CNTW'}

# %%
response_2["tracks"]["items"][0]["added_by"]["id"]
# Out:
# 'soyarepita'

# %% [markdown]
# #### Url + endpoint

# %%
query = url_base + playlist_id

# %%
query
# Out:
# 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTf6wqAsYxqz'

# %% [markdown]
# #### We make the request

# %%
response = requests.get(query, headers=headers).json()

# %%
response

# %%
response.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
def request_playlist (link):
    token = spotifyToken ()
    headers = {"Authorization":f"Bearer {token}"}
    
    url_base = "https://api.spotify.com/v1/playlists/"
    playlist_id = link.split("/")[-1].split("?")[0]
    
    query = url_base + playlist_id
        
    try:    
        return requests.get(query, headers=headers).json()
    except:
        token = spotifyToken ()
        return requests.get(query, headers=headers).json()

# %%
response.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
name = response["tracks"]["items"][0]["track"]["name"]
name
# Out:
# 'Quevedo: Bzrp Music Sessions, Vol. 52'

# %%
artist = response["tracks"]["items"][0]["track"]["artists"][0]["name"]
artist
# Out:
# 'Bizarrap'

# %%
album_name = response["tracks"]["items"][0]["track"]["album"]["name"]
album_name
# Out:
# 'Quevedo: Bzrp Music Sessions, Vol. 52'

# %%
popularity = response["tracks"]["items"][0]["track"]["popularity"]
popularity
# Out:
# 53

# %%
dict_ = {
    "name":name,
    "artist": artist,
    "album_name": album_name,
    "popularity": popularity
}

# %%
def info_for_one_song (one_song):
    
    name = one_song["track"]["name"]
    artist = one_song["track"]["artists"][0]["name"]
    album_name = one_song["track"]["album"]["name"]
    popularity = one_song["track"]["popularity"]
    user = one_song["added_by"]["id"]
    
    dict_ = {
    "name":name,
    "artist": artist,
    "album_name": album_name,
    "popularity": popularity,
    "user": user
}
    
    return dict_

# %%
# Tom: we could do random of any song

import random
maximum = len(response["tracks"]["items"])
value = random.randint(0, maximum)
info_for_one_song (response["tracks"]["items"][value])
# Out:
# {'name': 'Take Your Time (feat. Damien Jurado & Suli Breaks)',
#  'artist': 'Faithless',
#  'album_name': 'All Blessed',
#  'popularity': 39,
#  'user': 'lewtrah'}

# %%
info_for_one_song (response["tracks"]["items"][3])
# Out:
# {'name': 'As It Was',
#  'artist': 'Harry Styles',
#  'album_name': "Harry's House",
#  'popularity': 88,
#  'user': 'ferqwertyuiop'}

# %%
new_list = []

for i in response_2["tracks"]["items"]:
    new_list.append(info_for_one_song(i))

new_list
# Out:
# [{'name': 'Canto a Caracas',
#   'artist': "Billo's",
#   'album_name': 'Canto a Caracas',
#   'popularity': 0,
#   'user': 'soyarepita'},
#  {'name': 'Peces del Guaire',
#   'artist': 'Desorden Público',
#   'album_name': 'Descomposición',
#   'popularity': 3,
#   'user': 'soyarepita'},
#  {'name': 'Cerro Avila',
#   'artist': 'Ilan Chester',
#   'album_name': 'El Comienzo en un Sotano de la Florida',
#   'popularity': 0,
#   'user': 'soyarepita'},
#  {'name': 'Valle De Balas',
#   'artist': 'Desorden Público',
#   'album_name': 'Plomo Revienta',
#   'popularity': 22,
#   'user': 'marianamartinh'},
#  {'name': 'Las Caraqueñas',
#   'artist': 'Guaco',
#   'album_name': 'Guaco Es Guaco',
#   'popularity': 29,
#   'user': 'soyarepita'},
#  {'name': 'Epa Isidoro',
#   'artist': "Billo's",
#   'album_name': 'Canto a Caracas',
#   'popularity': 0,
#   'user': 'soyarepita'},
#  {'name': 'Caracas Tiene Su Guaguanco',
#   'artist': 'Justo Betancourt',
#   'album_name': 'Pa Bravo Yo',
#   'popularity': 0,
#   'user': '1253681944'},
#  {'name': 'Luna Caraqueña',
#   'artist': "Billo's",
#   'album_name': 'Canto a Caracas',
#   'popularity': 0,
#   'user': 'soyarepita'},
#  {'name': 'Caminando por Caracas',
#   'artist': 'Piero',
#   'album_name': 'Piero',
#   'popularity': 0,
#   'user': 'soyarepita'},
#  {'name': 'Caracas de Noche - Original Mix',
#   'artist': 'Javith',
#   'album_name': 'Caracas de Noche (Remixes)',
#   'popularity': 26,
#   'user': '1253681944'},
#  {'name': 'La Sifrina',
#   'artist': 'Medioevo',
#   'album_name': 'La Sifrina',
#   'popularity': 0,
#   'user': '1253681944'},
#  {'name': 'La Vecina',
#   'artist': 'Los Amigos Invisibles',
#   'album_name': 'Arepa 3000',
#   'popularity': 42,
#   'user': '1245001868'},
#  {'name': 'Caracas: Te Quiero _ _ _ _ _',
#   'artist': 'Masseratti 2Lts',
#   'album_name': 'Colores de Ideas #7',
#   'popularity': 13,
#   'user': '1245001868'},
#  {'name': 'La Hora De Caracas',
#   'artist': 'Telegrama',
#   'album_name': 'Cambia Tus Amigos',
#   'popularity': 0,
#   'user': '1245001868'},
#  {'name': 'En La Ciudad De La Furia - Remasterizado 2007',
#   'artist': 'Soda Stereo',
#   'album_name': 'Me Verás Volver (Hits & Más)',
#   'popularity': 50,
#   'user': 'marianamartinh'}]

# %% [markdown]
# Popularity: according to a 1second google search
#
#     Spotify's Popularity index is a 0-100 scale rating of how popular you are compared to every other artist on the platform. Some music marketing chatter suggests a PI of 20+ in the first few weeks will get you onto Release Radar and a PI of 30+ will get you onto Discover Weekly.

# %%
df = pd.DataFrame(new_list)
df
# Out:
#                                              name                 artist  \
# 0                                 Canto a Caracas                Billo's
# 1                                Peces del Guaire       Desorden Público
# 2                                     Cerro Avila           Ilan Chester
# 3                                  Valle De Balas       Desorden Público
# 4                                  Las Caraqueñas                  Guaco
# 5                                     Epa Isidoro                Billo's
# 6                      Caracas Tiene Su Guaguanco       Justo Betancourt
# 7                                 Luna Caraqueña                Billo's
# 8                           Caminando por Caracas                  Piero
# 9                 Caracas de Noche - Original Mix                 Javith
# 10                                     La Sifrina               Medioevo
# 11                                      La Vecina  Los Amigos Invisibles
# 12                   Caracas: Te Quiero _ _ _ _ _        Masseratti 2Lts
# 13                             La Hora De Caracas              Telegrama
# 14  En La Ciudad De La Furia - Remasterizado 2007            Soda Stereo
#
#                                 album_name  popularity            user
# 0                          Canto a Caracas           0      soyarepita
# 1                           Descomposición           3      soyarepita
# 2   El Comienzo en un Sotano de la Florida           0      soyarepita
# 3                           Plomo Revienta          22  marianamartinh
# 4                           Guaco Es Guaco          29      soyarepita
# 5                          Canto a Caracas           0      soyarepita
# 6                              Pa Bravo Yo           0      1253681944
# 7                          Canto a Caracas           0      soyarepita
# 8                                    Piero           0      soyarepita
# 9               Caracas de Noche (Remixes)          26      1253681944
# 10                              La Sifrina           0      1253681944
# 11                              Arepa 3000          42      1245001868
# 12                     Colores de Ideas #7          13      1245001868
# 13                       Cambia Tus Amigos           0      1245001868
# 14            Me Verás Volver (Hits & Más)          50  marianamartinh

# %%
# most maisntream?
df
# Out:
#                                              name                 artist  \
# 0                                 Canto a Caracas                Billo's
# 1                                Peces del Guaire       Desorden Público
# 2                                     Cerro Avila           Ilan Chester
# 3                                  Valle De Balas       Desorden Público
# 4                                  Las Caraqueñas                  Guaco
# 5                                     Epa Isidoro                Billo's
# 6                      Caracas Tiene Su Guaguanco       Justo Betancourt
# 7                                 Luna Caraqueña                Billo's
# 8                           Caminando por Caracas                  Piero
# 9                 Caracas de Noche - Original Mix                 Javith
# 10                                     La Sifrina               Medioevo
# 11                                      La Vecina  Los Amigos Invisibles
# 12                   Caracas: Te Quiero _ _ _ _ _        Masseratti 2Lts
# 13                             La Hora De Caracas              Telegrama
# 14  En La Ciudad De La Furia - Remasterizado 2007            Soda Stereo
#
#                                 album_name  popularity            user
# 0                          Canto a Caracas           0      soyarepita
# 1                           Descomposición           3      soyarepita
# 2   El Comienzo en un Sotano de la Florida           0      soyarepita
# 3                           Plomo Revienta          22  marianamartinh
# 4                           Guaco Es Guaco          29      soyarepita
# 5                          Canto a Caracas           0      soyarepita
# 6                              Pa Bravo Yo           0      1253681944
# 7                          Canto a Caracas           0      soyarepita
# 8                                    Piero           0      soyarepita
# 9               Caracas de Noche (Remixes)          26      1253681944
# 10                              La Sifrina           0      1253681944
# 11                              Arepa 3000          42      1245001868
# 12                     Colores de Ideas #7          13      1245001868
# 13                       Cambia Tus Amigos           0      1245001868
# 14            Me Verás Volver (Hits & Más)          50  marianamartinh

# %%
def group_by_popularity (df):
    return df.groupby("user").agg({"popularity": "mean"}).reset_index().sort_values(by="popularity", ascending=False)["user"][0]

# %%
df.groupby("user").agg({"popularity": "mean"}).reset_index().sort_values(by="popularity", ascending=False)["user"][0]
# Out:
# '1245001868'

# %%
# 1. Function that refreshes the .env
# 2. Does the request for the query: link
# 3. Processes the response into a dataframe
# 4. Groupby: name of the user by popularity

# %%
# input = link
# output = name

# %%
def all_together (link):
    response = request_playlist (link)
    list_ = [info_for_one_song(i) for i in response["tracks"]["items"]]
    df = pd.DataFrame (list_)
    return f"The most mainstream user in this playlist is: {group_by_popularity (df)}"

# %%
andres = "https://open.spotify.com/playlist/50v0ITLYuxui3QRwd0CNTW?si=3176623842434386"

# %%
all_together(andres)
# Out:
# 'The most mainstream user in this playlist is: 1245001868'

# %% [markdown]
# #### Function to extract info from dictionaries

# %% [markdown]
# ### We're taking it to Pandas! 🐼
# How? Easy....

# %%
df.to_csv("songs-andres.csv", index=False)

# %%
df = pd.read_csv("songs-andres.csv")
df
# Out:
#                                              name                 artist  \
# 0                                 Canto a Caracas                Billo's
# 1                                Peces del Guaire       Desorden Público
# 2                                     Cerro Avila           Ilan Chester
# 3                                  Valle De Balas       Desorden Público
# 4                                  Las Caraqueñas                  Guaco
# 5                                     Epa Isidoro                Billo's
# 6                      Caracas Tiene Su Guaguanco       Justo Betancourt
# 7                                 Luna Caraqueña                Billo's
# 8                           Caminando por Caracas                  Piero
# 9                 Caracas de Noche - Original Mix                 Javith
# 10                                     La Sifrina               Medioevo
# 11                                      La Vecina  Los Amigos Invisibles
# 12                   Caracas: Te Quiero _ _ _ _ _        Masseratti 2Lts
# 13                             La Hora De Caracas              Telegrama
# 14  En La Ciudad De La Furia - Remasterizado 2007            Soda Stereo
#
#                                 album_name  popularity            user
# 0                          Canto a Caracas           0      soyarepita
# 1                           Descomposición           3      soyarepita
# 2   El Comienzo en un Sotano de la Florida           0      soyarepita
# 3                           Plomo Revienta          22  marianamartinh
# 4                           Guaco Es Guaco          29      soyarepita
# 5                          Canto a Caracas           0      soyarepita
# 6                              Pa Bravo Yo           0      1253681944
# 7                          Canto a Caracas           0      soyarepita
# 8                                    Piero           0      soyarepita
# 9               Caracas de Noche (Remixes)          26      1253681944
# 10                              La Sifrina           0      1253681944
# 11                              Arepa 3000          42      1245001868
# 12                     Colores de Ideas #7          13      1245001868
# 13                       Cambia Tus Amigos           0      1245001868
# 14            Me Verás Volver (Hits & Más)          50  marianamartinh

# %% [markdown]
# # 📚 Recap so far:
#
# **What we did**
# - 0. We call the spotify API with a request of the type post so that it gives me the token
# - 1. We made a call to the Spotify API: to get the list information
# - 2. We get only the songs and artists from the json
# - 3. We make functions that automate processes and reuse code
# - 4. We have a dataframe
# <br>
#
# **To remember**
#
# - Add the `.env` to the `.gitignore`.

# %%
df.sample()
# Out:
#          name                 artist  album_name  popularity        user
# 11  La Vecina  Los Amigos Invisibles  Arepa 3000          42  1245001868

# %% [markdown]
# ## Mission 3: Get song lyrics

# %% [markdown]
# `Approach 1: SongLyrics library`

# %% [markdown]
# Lyrics extractor is a library that scribes some pages of song lyrics for us.
# We take a look at the [documentation](https://pypi.org/project/lyrics-extractor/) ALWAYS, especially the
#
# **Requirements** part that will explain the things we need to have for it to work .
#
# We need to create the KEYs for this library
# 1.1.1. **[First](https://cse.google.com/cse/create/new)**, create a custom search engine: select a website of letters to scrape. for example: www.genius.com <br>
# 1.1.2. **Second**, `Edit your search engine > select your website > Copy your search engine ID`.
# You now have your **GCS_ENGINE_ID**<br>
# 1.1.3. **[Then](https://developers.google.com/custom-search/v1/overview)**, `Get a key > Select project > copy search engine API key`. You now have your **GCS_API_KEY**.
#
# ```python
# from lyrics_extractor import SongLyrics
# extract_lyrics = SongLyrics(GCS_API_KEY, GCS_ENGINE_ID)
#
# sheeran = get_lyrics("Ed Sheeran", "shape of you")
# sheeran
# ```

# %% [markdown]
# `Approach 2: lyricsgenius`
#
# 1. Install lyrics genius
# 2. Sign up
# 3. Create an [API client](https://genius.com/api-clients)
#    - Use "https://whatever.com" as your website

# %%
#!pip install lyricsgenius
import lyricsgenius

# %% [markdown]
# ### store it in a variable
# We save the library in a variable by calling SongLyrics and passing it the keys

# %%
from getpass import getpass
gen = getpass()
# Out:
# ········

# %% [markdown]
# ### We are looking for some lyrics

# %%
genius = lyricsgenius.Genius(gen)

# %%
example = genius.search_artist("ROSALÍA", max_songs=1)
example
# Out:
# Searching for songs by ROSALÍA...
#
# Song 1: "MALAMENTE (Cap.1: Augurio)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Artist(id, songs, ...)

# %%
example
# Out:
# Artist(id, songs, ...)

# %%
artist = genius.search_artist("ROSALÍA", max_songs=1)
cancion = "con altura"
song = artist.song(cancion)
song.lyrics
# Out:
# Searching for songs by ROSALÍA...
#
# Song 1: "MALAMENTE (Cap.1: Augurio)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "con altura" by ROSALÍA...
# Done.
# 'TranslationsEnglishCon Altura Lyrics[Letra de "Con Altura" ft. El Guincho]\n\n[Intro: ROSALÍA & Mariachi Budda]\nEsto vamo\' a arrancarlo con altura\nEl dembow lo canto con hondura\nDicen: "Una estrella, una figura"\nDe Héctor aprendí la sabrosura\nNunca he visto una joya tan pura\n\n[Coro: El Guincho & ROSALÍA]\nEsto es pa\' que quede, lo que yo hago dura (Con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura)\nIré joven pa\' la sepultura (Con altura)\nEsto es pa\' que quede, lo que yo hago dura (Con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura)\nIré joven pa\' la sepultura (Con altura)\n[Verso 1: ROSALÍA]\nPongo rosas sobre el Panamera (Brrm)\nPongo palmas sobre la guantanamera\nLlevo a Camarón en la guantera (De la Isla)\nLo hago pa\' mi gente y lo hago a mi manera\n\n[Pre-Coro: ROSALÍA]\nFlores azules y quilates\nY si es mentira, que me maten\nFlores azules y quilates\nY si es mentira, que me maten\n(Con altura; con altura)\n\n[Coro: ROSALÍA & El Guincho]\nEsto es pa\' que quede, lo que yo hago dura (Con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura)\nIré joven pa\' la sepultura (Con altura)\nEsto es pa\' que quede, lo que yo hago dura (Con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura)\nIré joven pa\' la sepultura (Con altura)\n\n[Verso 2: J Balvin & ROSALÍA]\nAcá en la altura \'tán fuerte\' los viento\' (Wuh)\nPonte el cinturón y coge asiento\nA tu jeva ya la vi por dentro (Yes)\nEl dinero nunca pierde tiempo (No, no)\nContra la pared (Tú lo sabe\')\nY le tuve que comprar un trago\nPorque la tenías con sed (Wuh, wuh)\nDesde acá qué rico se ve (Woh)\nNo soy Sky, pero rompí el bajo otra vez (Wuh; mira)\nYou might also like[Pre-Coro: ROSALÍA & J Balvin, Ambos]\nFlores azules y quilates (Rosalía)\nY si es mentira, que me maten (J Balvin)\nFlores azules y quilates\nY si es mentira, que me maten\n(Con altura; con altura)\n\n[Coro: ROSALÍA, J Balvin & El Guincho]\nEsto es pa\' que quede, lo que yo hago dura (Con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura)\nIré joven pa\' la sepultura (Con altura)\nEsto es pa\' que quede, lo que yo hago dura (Siempre dura, dura; con altura)\nDemasiá\' noches de travesura (Con altura)\nVivo rápido y no tengo cura (Con altura; ajá)\nIré joven pa\' la sepultura (Con altura)\n\n[Outro: ROSALÍA, J Balvin & El Guincho]\nJ Balvin\nLa Rosalía\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\' que quede (Con altura)\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\'-pa\' que quede (Con altura)\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\'-pa\'-pa\' que quede (Con altura)\nDemasia\'o \'e embuste\nVamo\', vamo\' a-a, vamo\' a perrearnos, lo que yo hago dura\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\' que quede (Con altura)\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\'-pa\' que quede (Con altura)\nVamo\', vamo\' a-a, vamo\' a perrearnos, pa\'-pa\'-pa\' que quede (Con altura)\nDemasia\'o \'e embuste\nVamo\', vamo\' a-a, vamo\' a perrearnos, lo que yo hago dura25Embed'

# %% [markdown]
# ### Many lyrics!

# %%
print(song.lyrics)
# Out:
# TranslationsEnglishCon Altura Lyrics[Letra de "Con Altura" ft. El Guincho]
#
# [Intro: ROSALÍA & Mariachi Budda]
# Esto vamo' a arrancarlo con altura
# El dembow lo canto con hondura
# Dicen: "Una estrella, una figura"
# De Héctor aprendí la sabrosura
# Nunca he visto una joya tan pura
#
# [Coro: El Guincho & ROSALÍA]
# Esto es pa' que quede, lo que yo hago dura (Con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura)
# Iré joven pa' la sepultura (Con altura)
# Esto es pa' que quede, lo que yo hago dura (Con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura)
# Iré joven pa' la sepultura (Con altura)
# [Verso 1: ROSALÍA]
# Pongo rosas sobre el Panamera (Brrm)
# Pongo palmas sobre la guantanamera
# Llevo a Camarón en la guantera (De la Isla)
# Lo hago pa' mi gente y lo hago a mi manera
#
# [Pre-Coro: ROSALÍA]
# Flores azules y quilates
# Y si es mentira, que me maten
# Flores azules y quilates
# Y si es mentira, que me maten
# (Con altura; con altura)
#
# [Coro: ROSALÍA & El Guincho]
# Esto es pa' que quede, lo que yo hago dura (Con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura)
# Iré joven pa' la sepultura (Con altura)
# Esto es pa' que quede, lo que yo hago dura (Con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura)
# Iré joven pa' la sepultura (Con altura)
#
# [Verso 2: J Balvin & ROSALÍA]
# Acá en la altura 'tán fuerte' los viento' (Wuh)
# Ponte el cinturón y coge asiento
# A tu jeva ya la vi por dentro (Yes)
# El dinero nunca pierde tiempo (No, no)
# Contra la pared (Tú lo sabe')
# Y le tuve que comprar un trago
# Porque la tenías con sed (Wuh, wuh)
# Desde acá qué rico se ve (Woh)
# No soy Sky, pero rompí el bajo otra vez (Wuh; mira)
# You might also like[Pre-Coro: ROSALÍA & J Balvin, Ambos]
# Flores azules y quilates (Rosalía)
# Y si es mentira, que me maten (J Balvin)
# Flores azules y quilates
# Y si es mentira, que me maten
# (Con altura; con altura)
#
# [Coro: ROSALÍA, J Balvin & El Guincho]
# Esto es pa' que quede, lo que yo hago dura (Con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura)
# Iré joven pa' la sepultura (Con altura)
# Esto es pa' que quede, lo que yo hago dura (Siempre dura, dura; con altura)
# Demasiá' noches de travesura (Con altura)
# Vivo rápido y no tengo cura (Con altura; ajá)
# Iré joven pa' la sepultura (Con altura)
#
# [Outro: ROSALÍA, J Balvin & El Guincho]
# J Balvin
# La Rosalía
# Vamo', vamo' a-a, vamo' a perrearnos, pa' que quede (Con altura)
# Vamo', vamo' a-a, vamo' a perrearnos, pa'-pa' que quede (Con altura)
# Vamo', vamo' a-a, vamo' a perrearnos, pa'-pa'-pa' que quede (Con altura)
# Demasia'o 'e embuste
# Vamo', vamo' a-a, vamo' a perrearnos, lo que yo hago dura
# Vamo', vamo' a-a, vamo' a perrearnos, pa' que quede (Con altura)
# Vamo', vamo' a-a, vamo' a perrearnos, pa'-pa' que quede (Con altura)
# Vamo', vamo' a-a, vamo' a perrearnos, pa'-pa'-pa' que quede (Con altura)
# Demasia'o 'e embuste
# Vamo', vamo' a-a, vamo' a perrearnos, lo que yo hago dura25Embed

# %%
def get_lyrics (artist, song):
    try:
        artist_ = genius.search_artist(artist, max_songs=1)
        song_ = artist_.song(song)
        return song_.lyrics
    
    except:
        return np.nan

# %%
get_lyrics ("Oasis", "wonderwall")
# Out:
# Searching for songs by Oasis...
#
# Song 1: "Wonderwall"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "wonderwall" by Oasis...
# Done.
# "TranslationsEnglishWonderwall Lyrics[Verse 1]\nToday is gonna be the day that they're gonna throw it back to you\nAnd by now, you shoulda somehow realised what you gotta do\nI don't believe that anybody feels the way I do about you now\n\n[Verse 2]\nAnd backbeat, the word is on the street that the fire in your heart is out\nI'm sure you've heard it all before, but you never really had a doubt\nI don't believe that anybody feels the way I do about you now\n\n[Pre-Chorus]\nAnd all the roads we have to walk are winding\nAnd all the lights that lead us there are blinding\nThere are many things that I would like to say to you, but I don't know how\n[Chorus]\nBecause maybe\nYou're gonna be the one that saves me\nAnd after all\nYou're my wonderwall\n\n[Verse 3]\nToday was gonna be the day, but they'll never throw it back to you\nAnd by now, you shoulda somehow realised what you're not to do\nI don't believe that anybody feels the way I do about you now\n\n[Pre-Chorus]\nAnd all the roads that lead you there were winding\nAnd all the lights that light the way are blinding\nThere are many things that I would like to say to you, but I don't know how\n\n[Chorus]\nI said maybe\nYou're gonna be the one that saves me\nAnd after all\nYou're my wonderwall\nI said maybe (I said maybe)\nYou're gonna be the one that saves me\nAnd after all\nYou're my wonderwall\nYou might also like[Outro]\nI said maybe (I said maybe)\nYou're gonna be the one that saves me (That saves me)\nYou're gonna be the one that saves me (That saves me)\nYou're gonna be the one that saves me (That saves me)202Embed"

# %%
df.sample()
# Out:
#                               name  artist                  album_name  \
# 9  Caracas de Noche - Original Mix  Javith  Caracas de Noche (Remixes)
#
#    popularity        user
# 9          26  1253681944

# %%
def silly_function (x, y):
    return x + y

# %%
#df["lyrics_test"] = df.apply(silly_function (df["artist"], df["name"]), axis=1)

# %%
#df["lyrics"] = df.apply(get_lyrics (df["artist"], df["name"]), axis=1)

# %%
df["lyrics"] = df.apply(lambda row: get_lyrics (row["artist"], row["name"]), axis=1)
# Out:
# Searching for songs by Billo's...
#
# Changing artist name to 'Billo’s Caracas Boys'
# Song 1: "Navidad Que Vuelve"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Canto a Caracas" by Billo’s Caracas Boys...
# Done.
# Searching for songs by Desorden Público...
#
# Song 1: "Allá Cayó"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Peces del Guaire" by Desorden Público...
# No results found for: 'Peces del Guaire Desorden Público'
# Searching for songs by Ilan Chester...
#
# Song 1: "Palabras del alma"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cerro Avila" by Ilan Chester...
# No results found for: 'Cerro Avila Ilan Chester'
# Searching for songs by Desorden Público...
#
# Song 1: "Allá Cayó"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Valle De Balas" by Desorden Público...
# Done.
# Searching for songs by Guaco...
#
# Song 1: "Si Usted La Viera"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Las Caraqueñas" by Guaco...
# Done.
# Searching for songs by Billo's...
#
# Changing artist name to 'Billo’s Caracas Boys'
# Song 1: "Navidad Que Vuelve"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Epa Isidoro" by Billo’s Caracas Boys...
# No results found for: 'Epa Isidoro Billo’s Caracas Boys'
# Searching for songs by Justo Betancourt...
#
# Changing artist name to 'Justo betancourt'
# Song 1: "Pa Bravo Yo"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Caracas Tiene Su Guaguanco" by Justo betancourt...
# No results found for: 'Caracas Tiene Su Guaguanco Justo betancourt'
# Searching for songs by Billo's...
#
# Changing artist name to 'Billo’s Caracas Boys'
# Song 1: "Navidad Que Vuelve"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Luna Caraqueña" by Billo’s Caracas Boys...
# No results found for: 'Luna Caraqueña Billo’s Caracas Boys'
# Searching for songs by Piero...
#
# Changing artist name to 'Piero Pelù'
# Song 1: "Gigante"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Caminando por Caracas" by Piero Pelù...
# Done.
# Searching for songs by Javith...
#
# Changing artist name to 'Jesus Javith'
# Song 1: "This Love"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Caracas de Noche - Original Mix" by Jesus Javith...
# No results found for: 'Caracas de Noche - Original Mix Jesus Javith'
# Searching for songs by Medioevo...
#
# Changing artist name to 'Mediæval Bæbes'
# Song 1: "Kinderly"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "La Sifrina" by Mediæval Bæbes...
# No results found for: 'La Sifrina Mediæval Bæbes'
# Searching for songs by Los Amigos Invisibles...
#
# Song 1: "La Que Me Gusta"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "La Vecina" by Los Amigos Invisibles...
# Done.
# Searching for songs by Masseratti 2Lts...
#
# Changing artist name to 'Masseratti 2lts'
# Song 1: "Free Fresa SUN.dance Lovers"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Caracas: Te Quiero _ _ _ _ _" by Masseratti 2lts...
# No results found for: 'Caracas: Te Quiero _ _ _ _ _ Masseratti 2lts'
# Searching for songs by Telegrama...
#
# Changing artist name to 'Telegram (Band)'
# Song 1: "Follow"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "La Hora De Caracas" by Telegram (Band)...
# No results found for: 'La Hora De Caracas Telegram (Band)'
# Searching for songs by Soda Stereo...
#
# Song 1: "De Música Ligera"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "En La Ciudad De La Furia - Remasterizado 2007" by Soda Stereo...
# No results found for: 'En La Ciudad De La Furia - Remasterizado 2007 Soda Stereo'

# %% [markdown]
# # Export: csv

# %%
df
# Out:
#                                              name                 artist  \
# 0                                 Canto a Caracas                Billo's
# 1                                Peces del Guaire       Desorden Público
# 2                                     Cerro Avila           Ilan Chester
# 3                                  Valle De Balas       Desorden Público
# 4                                  Las Caraqueñas                  Guaco
# 5                                     Epa Isidoro                Billo's
# 6                      Caracas Tiene Su Guaguanco       Justo Betancourt
# 7                                 Luna Caraqueña                Billo's
# 8                           Caminando por Caracas                  Piero
# 9                 Caracas de Noche - Original Mix                 Javith
# 10                                     La Sifrina               Medioevo
# 11                                      La Vecina  Los Amigos Invisibles
# 12                   Caracas: Te Quiero _ _ _ _ _        Masseratti 2Lts
# 13                             La Hora De Caracas              Telegrama
# 14  En La Ciudad De La Furia - Remasterizado 2007            Soda Stereo
#
#                                 album_name  popularity            user  \
# 0                          Canto a Caracas           0      soyarepita
# 1                           Descomposición           3      soyarepita
# 2   El Comienzo en un Sotano de la Florida           0      soyarepita
# 3                           Plomo Revienta          22  marianamartinh
# 4                           Guaco Es Guaco          29      soyarepita
# 5                          Canto a Caracas           0      soyarepita
# 6                              Pa Bravo Yo           0      1253681944
# 7                          Canto a Caracas           0      soyarepita
# 8                                    Piero           0      soyarepita
# 9               Caracas de Noche (Remixes)          26      1253681944
# 10                              La Sifrina           0      1253681944
# 11                              Arepa 3000          42      1245001868
# 12                     Colores de Ideas #7          13      1245001868
# 13                       Cambia Tus Amigos           0      1245001868
# 14            Me Verás Volver (Hits & Más)          50  marianamartinh
#
#                                                lyrics
# 0   Scarface Script LyricsScarface\n\nBy: Oliver S...
# 1                                                 NaN
# 2                                                 NaN
# 3   Valle De Balas LyricsLa ciudad se encierra a v...
# 4   Las Caraqueñas LyricsNo sé que tienen las chic...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   CONGRESOS E INTELECTUALES EN LOS INICIOS DE UN...
# 9                                                 NaN
# 10                                                NaN
# 11  La Vecina Lyrics[Letra de "La Vecina"]\n\nToda...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN

# %%
df.to_csv("lyrics-andres.csv", index=False)

# %% [markdown]
# # RECAP

# %% [markdown]
# - Get lyrics from a given playlist
# - Signed up for the spotify API: cliend_id & client_secret
# - With that: do a POST request to send those credentials and get a token
# - With the token: we're able to get all the songs from a playlist
# - We use the genius library for python to use its API
# - We build a dataframe with all the lyrics from a given spotify playlist
#
# - We saved the code into functions
# - We also createad one to save things into .env
#
# - Reminder: .env & .gitignore
#
# - By putting all the functions together: we can build a script that by passing ONE link (provided you have spotify credentials): result is a pandas daraframe with songs & lryics
#
# Input: one link
# Output: a whole dataframe with info from two sources
