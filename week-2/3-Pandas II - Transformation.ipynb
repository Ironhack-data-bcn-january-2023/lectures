# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Basic-operations-with-dataframes" data-toc-modified-id="Basic-operations-with-dataframes-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Basic operations with dataframes</a></span><ul class="toc-item"><li><span><a href="#Select:-column" data-toc-modified-id="Select:-column-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Select: column</a></span></li><li><span><a href="#Select:-subset" data-toc-modified-id="Select:-subset-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Select: subset</a></span></li><li><span><a href="#Get-the-unique-values-​​of-a-column" data-toc-modified-id="Get-the-unique-values-​​of-a-column-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Get the unique values ​​of a column</a></span></li></ul></li><li><span><a href="#Filtering" data-toc-modified-id="Filtering-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Filtering</a></span><ul class="toc-item"><li><span><a href="#by-the-value-of-the-columns" data-toc-modified-id="by-the-value-of-the-columns-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>by the value of the columns</a></span></li><li><span><a href="#df.loc-&amp;-df.iloc" data-toc-modified-id="df.loc-&amp;-df.iloc-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>df.loc &amp; df.iloc</a></span><ul class="toc-item"><li><span><a href="#Based-on-label:-loc" data-toc-modified-id="Based-on-label:-loc-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Based on label: <code>loc</code></a></span></li><li><span><a href="#Based-on-index:--iloc" data-toc-modified-id="Based-on-index:--iloc-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Based on index:  <code>iloc</code></a></span></li></ul></li><li><span><a href="#Rename-columns" data-toc-modified-id="Rename-columns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Rename columns</a></span><ul class="toc-item"><li><span><a href="#Rename-columns" data-toc-modified-id="Rename-columns-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Rename columns</a></span></li></ul></li><li><span><a href="#Change-the-data-type-of-a-column" data-toc-modified-id="Change-the-data-type-of-a-column-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Change the data type of a column</a></span></li><li><span><a href="#Copy-a-dataframe" data-toc-modified-id="Copy-a-dataframe-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Copy a dataframe</a></span></li></ul></li><li><span><a href="#deleting" data-toc-modified-id="deleting-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>deleting</a></span><ul class="toc-item"><li><span><a href="#delete-columns" data-toc-modified-id="delete-columns-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>delete columns</a></span></li><li><span><a href="#delete-rows" data-toc-modified-id="delete-rows-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>delete rows</a></span></li></ul></li><li><span><a href="#working-with-the-index" data-toc-modified-id="working-with-the-index-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>working with the index</a></span></li><li><span><a href="#Operations-between-columns" data-toc-modified-id="Operations-between-columns-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Operations between columns</a></span><ul class="toc-item"><li><span><a href="#creating-columns" data-toc-modified-id="creating-columns-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>creating columns</a></span></li><li><span><a href="#apply:-mapping-a-function-to-columns-/-rows" data-toc-modified-id="apply:-mapping-a-function-to-columns-/-rows-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>apply: mapping a function to columns / rows</a></span></li></ul></li><li><span><a href="#Deleting-the-duplicates" data-toc-modified-id="Deleting-the-duplicates-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Deleting the duplicates</a></span></li><li><span><a href="#Null-values" data-toc-modified-id="Null-values-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Null values</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#It-is-null?" data-toc-modified-id="It-is-null?-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>It is null?</a></span></li><li><span><a href="#Is-NOT-null?" data-toc-modified-id="Is-NOT-null?-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Is NOT null?</a></span></li><li><span><a href="#Sum-the-null-values-​​of-each-column" data-toc-modified-id="Sum-the-null-values-​​of-each-column-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Sum the null values ​​of each column</a></span></li></ul></li><li><span><a href="#delete-null-values" data-toc-modified-id="delete-null-values-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>delete null values</a></span></li><li><span><a href="#How-to-fill-in-the-missing-data" data-toc-modified-id="How-to-fill-in-the-missing-data-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>How to fill in the missing data</a></span></li></ul></li><li><span><a href="#Export-data" data-toc-modified-id="Export-data-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Export data</a></span></li><li><span><a href="#Pandas-usual-methods" data-toc-modified-id="Pandas-usual-methods-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Pandas usual methods</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Further materials</a></span></li></ul></div>

# %% [markdown]
# ![](https://files.realpython.com/media/How-to-Speed-Up-Your-Pandas-Projects_Watermarked.87866cfe1bc2.jpg)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Basic operations with dataframes

# %% [markdown]
# ### Select: column

# %%
df = pd.read_csv("../datasets/Advertising.csv")
df.sample()
# Out:
#        TV  Radio  Newspaper  Sales
# 196  94.2    4.9        8.1    9.7

# %%
df.Sales
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
df["Sales"]
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ### Select: subset

# %%
df.sample()
# Out:
#         TV  Radio  Newspaper  Sales
# 154  187.8   21.1        9.5   15.6

# %%
# TV, Radio
    # Inputting a list keys
    # Call the columns: df["Sales"]

# %%
df["TV"] #Series: just the series
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
list(df.columns)
# Out:
# ['TV', 'Radio', 'Newspaper', 'Sales']

# %%
new_list_columns = list(df.columns)[:-1]

# %%
target_columns = {
    "TV": "dfhjdsjzhv<fAHJWfs",
    "Radio": 3434
}

# %%
df[target_columns] #you can pass a dictionary as an argument
# Out:
#         TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]

# %%
df[["TV", "Radio", "Newspaper"]] #DF: result of passing a list
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# ### Get the unique values ​​of a column

# %%
df = pd.read_csv("../datasets/avocado_kaggle.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.region
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %%
df["region"]
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %% [markdown]
# `df.column.unique()`

# %%
df.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %% [markdown]
# `df.column.value_counts()`

# %%
df["type"].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# ## Filtering

# %% [markdown]
# ### by the value of the columns

# %%
#df["type"].unique("organic")

# %%
#df["type"]["organic"]

# %%
#df["type"] == "organic"

# %%
condition_1 = df["type"] == "organic"

# %%
df[condition_1].head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9126           0  2015-12-27          1.83        989.55   8.16   88.59   0.0
# 9127           1  2015-12-20          1.89       1163.03  30.24  172.14   0.0
# 9128           2  2015-12-13          1.85        995.96  10.44  178.70   0.0
# 9129           3  2015-12-06          1.84       1158.42  90.29  104.18   0.0
# 9130           4  2015-11-29          1.94        831.69   0.00   94.73   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9126      892.80      892.80        0.00          0.0  organic  2015  Albany
# 9127      960.65      960.65        0.00          0.0  organic  2015  Albany
# 9128      806.82      806.82        0.00          0.0  organic  2015  Albany
# 9129      963.95      948.52       15.43          0.0  organic  2015  Albany
# 9130      736.96      736.96        0.00          0.0  organic  2015  Albany

# %%
df_organic = df[df["type"] == "organic"]
df_organic.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9126           0  2015-12-27          1.83        989.55   8.16   88.59   0.0
# 9127           1  2015-12-20          1.89       1163.03  30.24  172.14   0.0
# 9128           2  2015-12-13          1.85        995.96  10.44  178.70   0.0
# 9129           3  2015-12-06          1.84       1158.42  90.29  104.18   0.0
# 9130           4  2015-11-29          1.94        831.69   0.00   94.73   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9126      892.80      892.80        0.00          0.0  organic  2015  Albany
# 9127      960.65      960.65        0.00          0.0  organic  2015  Albany
# 9128      806.82      806.82        0.00          0.0  organic  2015  Albany
# 9129      963.95      948.52       15.43          0.0  organic  2015  Albany
# 9130      736.96      736.96        0.00          0.0  organic  2015  Albany

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 2455          11  2015-10-11             0      88580.07  11289.75  56878.37
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 2455  1932.9    18479.05    18479.05         0.0          0.0  conventional
#
#       year   region
# 2455  2015  Spokane

# %%
# type: organic
# AveragePrice < 1

# %%
condition_organic = df["type"] == "organic" #serie of booleans
condition_avg_price = df["AveragePrice"] < 1 #serie of booleans

# %%
df[condition_organic].sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume   4046    4225  \
# 16374          43  2017-03-05             1      15016.27  76.78  269.38
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 16374   0.0    14670.11    14670.11         0.0          0.0  organic  2017
#
#                    region
# 16374  NorthernNewEngland

# %%
df[condition_organic & condition_avg_price].sample() #and
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046   4225  \
# 15737          42  2017-03-12             0      52810.48  13678.39  40.61
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 15737   0.0    39091.48    18616.19    20475.29          0.0  organic  2017
#
#         region
# 15737  Houston

# %%
df[condition_organic | condition_avg_price].sample() #or
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume   4046      4225  \
# 15178          13  2017-10-01             1      31903.97  61.05  25186.76
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 15178   0.0     6656.16     6656.16         0.0          0.0  organic  2017
#
#         region
# 15178  Chicago

# %%
# condition 1
    #type: organic
    
    # cndition 2
        #price < 1
    # condition 3
        # price > 1.8
    
    
#condition_1 AND (condition_2 OR condition 3)
# avg price -> 0-1, 1.8 >

# %%
condition_1 = (df["type"] == "organic")
condition_2 = (df.AveragePrice < 1)
condition_3 = (df.AveragePrice > 1.8)

# %% [markdown]
# `watch out for | symbol`

# %%
new_filtered = df[condition_1 & (condition_2 | condition_3)]
new_filtered.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9145          19  2015-08-16             2       1467.23  24.56  168.41   0.0
# 9147          21  2015-08-02             2       1223.94  17.66  103.62   0.0
# 9148          22  2015-07-26             2       1449.04  99.16  165.27   0.0
# 9149          23  2015-07-19             2       1076.23  50.86  112.36   0.0
# 9150          24  2015-07-12             2       1175.34  34.27   92.17   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9145     1274.26     1274.26         0.0          0.0  organic  2015  Albany
# 9147     1102.66     1102.66         0.0          0.0  organic  2015  Albany
# 9148     1184.61     1184.61         0.0          0.0  organic  2015  Albany
# 9149      913.01      913.01         0.0          0.0  organic  2015  Albany
# 9150     1048.90     1048.90         0.0          0.0  organic  2015  Albany

# %%
df["AveragePrice"].max()
# Out:
# 3

# %%
new_filtered["type"].value_counts()
# Out:
# organic    1677
# Name: type, dtype: int64

# %%
df.AveragePrice.mean()
# Out:
# 0.9263521288837745

# %%
new_filtered["AveragePrice"].mean()
# Out:
# 1.6994633273703041

# %%
df.shape
# Out:
# (18249, 14)

# %%
new_filtered.shape
# Out:
# (1677, 14)

# %%
# 1. Condition: Detroit
# 2. AveragePrice < 1
# 3: year: I dont like 
    # either before 2016
    # after 2017
# 4. type: conventional

# %%
condition_1 = df["region"] == "Detroit"
condition_2 = df["AveragePrice"] < 1
condition_3 = df.year < 2016
condition_4 = df.year > 2017
condition_5 = df.type == "conventional"

# %%
df_filtered = df[condition_1 & condition_2 & (condition_3 | condition_4) &  condition_5]
df_filtered.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 8643           9  2018-01-21             0     570161.95  87365.29  220100.47
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 8643  46163.59    216532.6   146574.63    65171.17       4786.8  conventional
#
#       year   region
# 8643  2018  Detroit

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume   4046     4225  \
# 14403          26  2016-06-26             1       3011.21  411.5  2059.45
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 14403   0.0      540.26       22.65      517.61          0.0  organic  2016
#
#         region
# 14403  Spokane

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      0.926352  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.477750  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.000000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.000000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.000000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.000000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.000000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %% [markdown]
# ### df.loc & df.iloc

# %%
df.shape[0]
# Out:
# 18249

# %%
df = pd.read_csv("../datasets/avocado_kaggle.csv").set_index("year")
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# year
# 2015           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2015           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2015           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 2015           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 2015           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2015   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2015  130.50     8145.35     8042.21      103.14          0.0  conventional
# 2015   72.58     5811.16     5677.40      133.76          0.0  conventional
# 2015   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#       region
# year
# 2015  Albany
# 2015  Albany
# 2015  Albany
# 2015  Albany
# 2015  Albany

# %% [markdown]
# `df.iloc[rows, columns]`

# %%
df.head(1)
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# year
# 2015           0  2015-12-27          1.33      64236.62  1036.74  54454.85
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015  48.16     8696.87     8603.62       93.25          0.0  conventional
#
#       region
# year
# 2015  Albany

# %%
df.iloc[0, 1]
# Out:
# '2015-12-27'

# %%
df.loc[2015, "Date"]
# Out:
# year
# 2015    2015-12-27
# 2015    2015-12-20
# 2015    2015-12-13
# 2015    2015-12-06
# 2015    2015-11-29
#            ...
# 2015    2015-02-01
# 2015    2015-01-25
# 2015    2015-01-18
# 2015    2015-01-11
# 2015    2015-01-04
# Name: Date, Length: 5615, dtype: object

# %%
df.iloc[:, 1:-6]
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770
# year
# 2015  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 2018  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 2018  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 2018  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 2018  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 2018  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
# [18249 rows x 6 columns]

# %%
df.loc[2015][:3] #Label -> look up things up to 2023
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# year
# 2015           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2015           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2015           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2015   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2015  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#       region
# year
# 2015  Albany
# 2015  Albany
# 2015  Albany

# %%
df.iloc[:3] # -> loking up things up to the length of the df (df.shape[0])
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# year
# 2015           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2015           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2015           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2015   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2015  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#       region
# year
# 2015  Albany
# 2015  Albany
# 2015  Albany

# %%
df = pd.DataFrame({"col1" : np.arange(1,20,2)}, index=[9,8,7,6,0, 1, 2, 3, 4, 5])
df
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19

# %% [markdown]
# #### Based on label: `loc`

# %% [markdown]
# The loc method can be used in two different ways: select rows or columns based on a label, or select rows or columns based on a condition.

# %%
df.loc[0:5]
# Out:
#    col1
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19

# %%
df.loc[0:5].sum()
# Out:
# col1    84
# dtype: int64

# %% [markdown]
# #### Based on index:  `iloc`

# %% [markdown]
# The iloc method is used on DataFrames to select elements based on their location. Its syntax is data.iloc[<filas>, <columnas>], where <filas> and <columnas> are the position of the rows and columns that you want to select in the order that they appear in the object. A familiar notation for Matlab users. In a DataFrame, each of the rows has a number that goes from 0 to the total number of rows minus one. Being iloc the method that allows selecting the data based on these numbers. The same applies to columns.
#
# In iloc there are two arguments rows and columns. In case the second is omitted, all columns in the row will be selected. So to select different rows can be used.

# %%
df.iloc[0:5]
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9

# %%
df.iloc[0:5].sum()
# Out:
# col1    25
# dtype: int64

# %% [markdown]
# loc syntax with multiple conditions
# ```python
# df.loc[(df["column"] condition) & (df["column"] condition)]
# ````

# %%
# IF INDEX: IS INT -> iloc & loc will give you different results

# %%
#by LABEL: Loc
# by INDEX: Iloc

# %% [markdown]
# ### Rename columns

# %% [markdown]
# #### Rename columns

# %% [markdown]
# `.rename(dict_)`

# %%
df.sample()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume       4046      4225  \
# 647          23  2015-07-19             1     857872.86  119266.12  513055.1
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 647  17089.18   208462.46    68585.03   139859.47        17.96  conventional
#
#      year  region
# 647  2015  Denver

# %%
print(list(df.columns))
# Out:
# ['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region']

# %% [markdown]
# The rename method allows me to rename only the columns that I want, the ones that are in the dictionary. No need to rename all at once

# %%
df.rename(columns={"Total Volume": "total_volume"}, inplace=True)

# %%
columns_dict = {i: i.lower().replace(" ", "").replace(":", "") for i in list(df.columns)}
columns_dict
# Out:
# {'Unnamed: 0': 'unnamed0',
#  'Date': 'date',
#  'AveragePrice': 'averageprice',
#  'total_volume': 'total_volume',
#  '4046': '4046',
#  '4225': '4225',
#  '4770': '4770',
#  'Total Bags': 'totalbags',
#  'Small Bags': 'smallbags',
#  'Large Bags': 'largebags',
#  'XLarge Bags': 'xlargebags',
#  'type': 'type',
#  'year': 'year',
#  'region': 'region'}

# %%
df.rename(columns = columns_dict).tail()
# Out:
#        unnamed0        date  averageprice  total_volume     4046     4225  \
# 18244         7  2018-02-04             1      17074.83  2046.96  1529.20
# 18245         8  2018-01-28             1      13888.04  1191.70  3431.50
# 18246         9  2018-01-21             1      13766.76  1191.92  2452.79
# 18247        10  2018-01-14             1      16205.22  1527.63  2981.04
# 18248        11  2018-01-07             1      17489.58  2894.77  2356.13
#
#          4770  totalbags  smallbags  largebags  xlargebags     type  year  \
# 18244    0.00   13498.67   13066.82     431.85         0.0  organic  2018
# 18245    0.00    9264.84    8940.04     324.80         0.0  organic  2018
# 18246  727.94    9394.11    9351.80      42.31         0.0  organic  2018
# 18247  727.01   10969.54   10919.54      50.00         0.0  organic  2018
# 18248  224.53   12014.15   11988.14      26.01         0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  total_volume     4046    4225  \
# 14559          26  2016-06-26             1       5867.74  2331.84  142.57
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 14559   0.0     3393.33      3370.0       23.33          0.0  organic  2016
#
#       region
# 14559  Tampa

# %%
#df.rename(columns={"A": "a", "B": "b", "C": "c"}, errors="raise")

# %% [markdown]
# `overwriting attributes`: Requires a list with the same number of columns

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Date',
#  'AveragePrice',
#  'total_volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
df.columns = [i.lower().replace(" ", "_").replace(":", "") for i in list(df.columns)]
df.columns
# Out:
# Index(['unnamed_0', 'date', 'averageprice', 'total_volume', '4046', '4225',
#        '4770', 'total_bags', 'small_bags', 'large_bags', 'xlarge_bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# ### Change the data type of a column

# %%
# df.dtypes

# %%
df["AveragePrice"] = df["AveragePrice"].astype("int")
df["AveragePrice"] 

# another approach: define a functipon and apply it to a column
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 18244    1
# 18245    1
# 18246    1
# 18247    1
# 18248    1
# Name: AveragePrice, Length: 18249, dtype: int64

# %%
df.dtypes #object = string
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice      int64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# ### Copy a dataframe

# %%
a_new_copy = df.copy()
a_new_copy.sample()
# Out:
#    col1
# 7     5

# %%
df.sample()
# Out:
#       unnamed_0        date  averageprice  total_volume     4046      4225  \
# 4606         30  2016-05-29             1     117486.96  1336.42  68421.33
#
#          4770  total_bags  small_bags  large_bags  xlarge_bags          type  \
# 4606  1567.32    46161.89     29242.9    16522.32       396.67  conventional
#
#       year      region
# 4606  2016  Pittsburgh

# %% [markdown]
# ## deleting

# %% [markdown]
# ### delete columns

# %%
df.sample()
# Out:
#      unnamed_0        date  averageprice  total_volume      4046       4225  \
# 502         34  2015-05-03             1     238140.96  11468.92  162213.47
#
#         4770  total_bags  small_bags  large_bags  xlarge_bags          type  \
# 502  7282.09    57176.48    18315.96    37361.33      1499.19  conventional
#
#      year            region
# 502  2015  CincinnatiDayton

# %%
# unnamed_0
# Unnamed: 0
#df.drop(columns=["unnamed_0"], inplace=True)

# %%
df.sample()
# Out:
#       unnamed_0        date  averageprice  total_volume       4046      4225  \
# 3783         39  2016-03-27             0    1345865.16  553962.21  406713.3
#
#            4770  total_bags  small_bags  large_bags  xlarge_bags  \
# 3783  177919.58   207270.07    75819.34    124377.4      7073.33
#
#               type  year   region
# 3783  conventional  2016  Houston

# %%
df.sample()
# Out:
#       unnamed_0        date  averageprice  total_volume       4046      4225  \
# 1265         17  2015-08-30             1     362232.28  212188.58  66569.74
#
#        4770  total_bags  small_bags  large_bags  xlarge_bags          type  \
# 1265  73.73    83400.23    59815.95    23581.37         2.91  conventional
#
#       year             region
# 1265  2015  MiamiFtLauderdale

# %%
df.drop(columns = ["year"], inplace=False, axis=1)
# Out:
#        unnamed_0        date  averageprice  total_volume     4046       4225  \
# 0              0  2015-12-27             1      64236.62  1036.74   54454.85
# 1              1  2015-12-20             1      54876.98   674.28   44638.81
# 2              2  2015-12-13             0     118220.22   794.70  109149.67
# 3              3  2015-12-06             1      78992.15  1132.00   71976.41
# 4              4  2015-11-29             1      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 18244          7  2018-02-04             1      17074.83  2046.96    1529.20
# 18245          8  2018-01-28             1      13888.04  1191.70    3431.50
# 18246          9  2018-01-21             1      13766.76  1191.92    2452.79
# 18247         10  2018-01-14             1      16205.22  1527.63    2981.04
# 18248         11  2018-01-07             1      17489.58  2894.77    2356.13
#
#          4770  total_bags  small_bags  large_bags  xlarge_bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
# Forcin error: not found in axis when dropping

df = pd.DataFrame({'team': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
                   'assists': [5, 7, 7, 9, 12, 9, 9, 4],
                   'points': [11, 8, 10, 6, 6, 5, 9, 12]})
df
# Out:
#   team  assists  points
# 0    A        5      11
# 1    A        7       8
# 2    A        7      10
# 3    A        9       6
# 4    B       12       6
# 5    B        9       5
# 6    B        9       9
# 7    B        4      12

# %%
#df.drop(['points', "team"], axis=1, inplace=True) #KeyError: "['points' 'team'] not found in axis"

# %%
df_new = df.drop('points', axis= 1) # KeyError: "['points'] not found in axis"

# %%
df_new
# Out:
#   team  assists
# 0    A        5
# 1    A        7
# 2    A        7
# 3    A        9
# 4    B       12
# 5    B        9
# 6    B        9
# 7    B        4

# %% [markdown]
# ### delete rows

# %%
df = pd.read_csv("../datasets/avocado_kaggle.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.drop([0, 1, 2, 3, 4, 5, 6, 7, 8], axis=0, inplace=False)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 9               9  2015-10-25          1.07      74338.76   842.40  64757.44
# 10             10  2015-10-18          1.12      84843.44   924.86  75595.85
# 11             11  2015-10-11          1.28      64489.17  1582.03  52677.92
# 12             12  2015-10-04          1.31      61007.10  2268.32  49880.67
# 13             13  2015-09-27          0.99     106803.39  1204.88  99409.21
# ...           ...         ...           ...           ...      ...       ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96   1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70   3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92   2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63   2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77   2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 9      113.00     8625.92     8061.47      564.45          0.0  conventional
# 10     117.07     8205.66     7877.86      327.80          0.0  conventional
# 11     105.32    10123.90     9866.27      257.63          0.0  conventional
# 12     101.36     8756.75     8379.98      376.77          0.0  conventional
# 13     154.84     6034.46     5888.87      145.59          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 9      2015            Albany
# 10     2015            Albany
# 11     2015            Albany
# 12     2015            Albany
# 13     2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18240 rows x 14 columns]

# %% [markdown]
# Rows can also be deleted. Note that the indexes are not reset. The index is associated with the row, not the order.
# Can the index be restarted? Correct

# %% [markdown]
# ## working with the index

# %% [markdown]
# We read the [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html) to understand some parameters

# %% [markdown]
# `set_index`

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046      4225  \
# 5434          26  2016-06-26          1.16     361181.98  143485.88  88209.18
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 5434  37.04   129449.88    88532.88     31127.0       9790.0  conventional
#
#       year region
# 5434  2016  Tampa

# %%
df.set_index("year", inplace=False)
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# year
# 2015           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2015           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2015           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 2015           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 2015           4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 2018           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 2018           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 2018           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 2018          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 2018          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2015   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2015  130.50     8145.35     8042.21      103.14          0.0  conventional
# 2015   72.58     5811.16     5677.40      133.76          0.0  conventional
# 2015   75.78     6183.95     5986.26      197.69          0.0  conventional
# ...      ...         ...         ...         ...          ...           ...
# 2018    0.00    13498.67    13066.82      431.85          0.0       organic
# 2018    0.00     9264.84     8940.04      324.80          0.0       organic
# 2018  727.94     9394.11     9351.80       42.31          0.0       organic
# 2018  727.01    10969.54    10919.54       50.00          0.0       organic
# 2018  224.53    12014.15    11988.14       26.01          0.0       organic
#
#                 region
# year
# 2015            Albany
# 2015            Albany
# 2015            Albany
# 2015            Albany
# 2015            Albany
# ...                ...
# 2018  WestTexNewMexico
# 2018  WestTexNewMexico
# 2018  WestTexNewMexico
# 2018  WestTexNewMexico
# 2018  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %% [markdown]
# `reset_index`

# %%
df.drop([0, 1, 2, 3, 4, 5, 6, 7, 8], axis=0, inplace=True)

# %%
df.head()
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 9            9  2015-10-25          1.07      74338.76   842.40  64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86  75595.85
# 11          11  2015-10-11          1.28      64489.17  1582.03  52677.92
# 12          12  2015-10-04          1.31      61007.10  2268.32  49880.67
# 13          13  2015-09-27          0.99     106803.39  1204.88  99409.21
#
#       4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 9   113.00     8625.92     8061.47      564.45          0.0  conventional
# 10  117.07     8205.66     7877.86      327.80          0.0  conventional
# 11  105.32    10123.90     9866.27      257.63          0.0  conventional
# 12  101.36     8756.75     8379.98      376.77          0.0  conventional
# 13  154.84     6034.46     5888.87      145.59          0.0  conventional
#
#     year  region
# 9   2015  Albany
# 10  2015  Albany
# 11  2015  Albany
# 12  2015  Albany
# 13  2015  Albany

# %%
df["AveragePrice"][9]
# Out:
# 1.07

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046     4225  \
# 12926          14  2016-09-18          1.96       2874.38  242.62  1484.61
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 12926   0.0     1147.15       514.7      632.45          0.0  organic  2016
#
#              region
# 12926  Indianapolis

# %% [markdown]
# What can we use to have the date as an index?
# We will see it later, to analyze temporary series

# %%
# index: unique
# an order
# maybe  before passing it to new libraries

# %% [markdown]
# ## Operations between columns

# %% [markdown]
# ### creating columns

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 6590          29  2017-06-11          0.89    1240308.02  627610.5  201534.03
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 6590  5451.76   405711.73   200221.42   205490.31          0.0  conventional
#
#       year   region
# 6590  2017  Houston

# %% [markdown]
# `as the result of an operation between other columns`

# %%
df["quantity"] = df["AveragePrice"] * df["Total Volume"]

# %%
df["quantity"] = df["quantity"] * 10

# %%
df["quantity_2"] = df["quantity"].apply(lambda x: str(x/10)[:4] + " €")

# %%
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046     4225  \
# 15229          20  2017-08-13          1.97       7797.08  219.37  4075.78
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 15229   0.0     3432.91     2701.68      731.23          0.0  organic  2017
#
#                  region    quantity quantity_2
# 15229  CincinnatiDayton  153602.476     1536 €

# %%
dict_ = {
    "age": 40
}

# %%
dict_["name"] = "Alberto"

# %%
dict_
# Out:
# {'age': 40, 'name': 'Alberto'}

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 3163           0  2016-12-25          1.25     155793.03  36125.58  50792.48
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 3163  7324.64    61550.33    51247.91    10232.98        69.44  conventional
#
#       year     region     quantity quantity_2
# 3163  2016  Charlotte  1947412.875     1947 €

# %%
df.shape
# Out:
# (18240, 16)

# %%
len(df.index)
# Out:
# 18240

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18240, step=1)

# %%
df.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 18235    2018
# 18236    2018
# 18237    2018
# 18238    2018
# 18239    2018
# Name: year, Length: 18240, dtype: int64

# %%
df.set_index("year", inplace=True)

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# year
# 2015          11  2015-10-11          1.01     118009.81  53713.89  37828.75
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015  151.21    26315.96    26312.88        3.08          0.0  conventional
#
#        region     quantity quantity_2
# year
# 2015  Roanoke  1191899.081     1191 €

# %%
df.index
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
#            dtype='int64', name='year', length=18240)

# %%
len(df.index)
# Out:
# 18240

# %%
df["year_2"] = df.index

# %%
df.drop(columns = "quantity_2", axis = 1, inplace=False)
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# year
# 2015           9  2015-10-25          1.07      74338.76   842.40  64757.44
# 2015          10  2015-10-18          1.12      84843.44   924.86  75595.85
# 2015          11  2015-10-11          1.28      64489.17  1582.03  52677.92
# 2015          12  2015-10-04          1.31      61007.10  2268.32  49880.67
# 2015          13  2015-09-27          0.99     106803.39  1204.88  99409.21
# ...          ...         ...           ...           ...      ...       ...
# 2018           7  2018-02-04          1.63      17074.83  2046.96   1529.20
# 2018           8  2018-01-28          1.71      13888.04  1191.70   3431.50
# 2018           9  2018-01-21          1.87      13766.76  1191.92   2452.79
# 2018          10  2018-01-14          1.93      16205.22  1527.63   2981.04
# 2018          11  2018-01-07          1.62      17489.58  2894.77   2356.13
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# year
# 2015  113.00     8625.92     8061.47      564.45          0.0  conventional
# 2015  117.07     8205.66     7877.86      327.80          0.0  conventional
# 2015  105.32    10123.90     9866.27      257.63          0.0  conventional
# 2015  101.36     8756.75     8379.98      376.77          0.0  conventional
# 2015  154.84     6034.46     5888.87      145.59          0.0  conventional
# ...      ...         ...         ...         ...          ...           ...
# 2018    0.00    13498.67    13066.82      431.85          0.0       organic
# 2018    0.00     9264.84     8940.04      324.80          0.0       organic
# 2018  727.94     9394.11     9351.80       42.31          0.0       organic
# 2018  727.01    10969.54    10919.54       50.00          0.0       organic
# 2018  224.53    12014.15    11988.14       26.01          0.0       organic
#
#                 region     quantity  year_2
# year
# 2015            Albany   795424.732    2015
# 2015            Albany   950246.528    2015
# 2015            Albany   825461.376    2015
# 2015            Albany   799193.010    2015
# 2015            Albany  1057353.561    2015
# ...                ...          ...     ...
# 2018  WestTexNewMexico   278319.729    2018
# 2018  WestTexNewMexico   237485.484    2018
# 2018  WestTexNewMexico   257438.412    2018
# 2018  WestTexNewMexico   312760.746    2018
# 2018  WestTexNewMexico   283331.196    2018
#
# [18240 rows x 15 columns]

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume    4046     4225  \
# year
# 2017           7  2017-11-12          1.81       6581.85  2473.4  2399.57
#
#       4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  \
# year
# 2017   0.0     1708.88     1708.88         0.0          0.0  organic
#
#           region    quantity quantity_2  year_2
# year
# 2017  Sacramento  119131.485     1191 €    2017

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 3121          10  2016-10-16           1.4    4878037.64  1635631.14
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 3121  1600568.32  108458.09  1533380.09  1423671.38    73117.52     36591.19
#
#               type      region     quantity quantity_2  year_2
# 3121  conventional  California  68292526.96     6829 €    2016

# %%
df.drop(df.columns[0], inplace=True, axis=1)

# %%
len(df.index) == len(set(df.index))
# Out:
# True

# %%
df.sample()
# Out:
#              Date  AveragePrice  Total Volume    4046      4225  4770  \
# 11305  2015-11-29          2.58      13218.02  953.12  12235.08   0.0
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type        region  \
# 11305       29.82        3.15       26.67          0.0  organic  SanFrancisco
#
#          quantity quantity_2  year_2
# 11305  341024.916     3410 €    2015

# %%
df["new"] = df["Total Volume"] + df["4046"]

# %%
df.sample()
# Out:
#            Date  AveragePrice  Total Volume     4046       4225     4770  \
# 475  2015-09-06          1.02     232157.91  2462.55  154106.32  8956.92
#
#      Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 475    66632.12    19499.39    45312.94      1819.79  conventional
#
#                region     quantity quantity_2  year_2        new
# 475  CincinnatiDayton  2368010.682     2368 €    2015  234620.46

# %% [markdown]
# ### apply: mapping a function to columns / rows

# %% [markdown]
# `apply to a pd.Series`

# %%
#map(power, [1, 2, 3])
#Series.apply(power)

# %%
df = pd.read_csv("../datasets/avocado_kaggle.csv")
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046      4225  \
# 6778          49  2017-01-22          0.79     382850.78  133276.27  64435.68
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 6778  6954.72   178184.11    44375.39   133739.28        69.44  conventional
#
#       year    region
# 6778  2017  LasVegas

# %%
df["type"]
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type, Length: 18249, dtype: object

# %%
df["type"] = df["type"].apply(uppercase)
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  CONVENTIONAL
# 1   58.33     9505.56     9408.07       97.49          0.0  CONVENTIONAL
# 2  130.50     8145.35     8042.21      103.14          0.0  CONVENTIONAL
# 3   72.58     5811.16     5677.40      133.76          0.0  CONVENTIONAL
# 4   75.78     6183.95     5986.26      197.69          0.0  CONVENTIONAL
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
def sentence_formatted (x):
    return f"This is of type: {x}"

# %%
df["sentence"] = df["type"].apply(sentence_formatted)

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 6212          13  2017-10-01           1.3      893387.5  492841.54
#
#            4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 6212  170718.08  876.26   228951.62   147483.78    81358.86       108.98
#
#               type  year         region                       sentence
# 6212  CONVENTIONAL  2017  DallasFtWorth  This is of type: CONVENTIONAL

# %%
# 1. lambda: into upper()
df["type"] = df["type"].apply(lambda x: x.upper())

# %%
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046     4225  \
# 11184          30  2015-05-31          0.98      18116.76  118.86  12165.3
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 11184   0.0      5832.6     1314.97     4517.63          0.0  organic  2015
#
#         region                  sentence
# 11184  Roanoke  This is of type: ORGANIC

# %%
# 2. formatted string


df["type"] = df["type"].apply(lambda x : f"This is type: {x.lower()}")

# %%
df.sample(3)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 8435           10  2017-10-22          1.04     673664.68  390067.16
# 2306           18  2015-08-23          1.09     310381.51  139531.80
# 15477          47  2017-02-05          0.85      16174.94     741.19
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 8435   159230.47   2000.47   122366.58    63878.87    58487.71          0.0
# 2306    64117.55  17089.65    89642.51    84625.03     5017.48          0.0
# 15477    4326.69      0.00    11107.06      681.27    10425.79          0.0
#
#                                            type  year            region  \
# 8435   This is type: this is type: conventional  2017  WestTexNewMexico
# 2306   This is type: this is type: conventional  2015     SouthCarolina
# 15477       This is type: this is type: organic  2017           Detroit
#
#                             sentence
# 8435   This is of type: CONVENTIONAL
# 2306   This is of type: CONVENTIONAL
# 15477       This is of type: ORGANIC

# %%
# 3. If AvgPrice > 1: "expensive"
# otherwise > affordable
# new_column

# "expensive" and "affordable"

df["new_column"] = df.AveragePrice.apply(lambda x: "expensive" if x > 1 else "affordable")
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 14123           6  2016-11-13          2.99       18930.4  6204.65  9341.41
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 14123   0.0     3384.34     3337.67       46.67          0.0
#
#                                       type  year        region  \
# 14123  This is type: this is type: organic  2016  SanFrancisco
#
#                        sentence new_column
# 14123  This is of type: ORGANIC  expensive

# %%
df.sample(5)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 16036          23  2017-07-23          1.41       4954.86       22.07
# 5514            2  2016-12-11          0.84    6648833.68  1687192.84
# 3908            8  2016-10-30          1.16     223089.05    79018.69
# 10657          23  2015-07-19          2.07      47878.48     3613.49
# 6825           43  2017-03-05          0.99    2768930.88   897311.08
#
#              4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 16036       27.40      0.00     4905.39     4902.06        3.33         0.00
# 5514   1545122.38  86234.32  3330284.14  2543800.78   778604.87      7878.49
# 3908     31778.97   7157.69   105133.70    42630.66    62503.04         0.00
# 10657    20743.86     93.68    23427.45    23396.97       30.48         0.00
# 6825    518369.51  83307.14  1269943.15  1214991.20     6376.28     48575.67
#
#                                            type  year             region  \
# 16036       This is type: this is type: organic  2017  MiamiFtLauderdale
# 5514   This is type: this is type: conventional  2016               West
# 3908   This is type: this is type: conventional  2016           LasVegas
# 10657       This is type: this is type: organic  2015          Northeast
# 6825   This is type: this is type: conventional  2017         LosAngeles
#
#                             sentence  new_column
# 16036       This is of type: ORGANIC   expensive
# 5514   This is of type: CONVENTIONAL  affordable
# 3908   This is of type: CONVENTIONAL   expensive
# 10657       This is of type: ORGANIC   expensive
# 6825   This is of type: CONVENTIONAL  affordable

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region', 'sentence', 'new_column'],
#       dtype='object')

# %%
columns_sorted = sorted([i for i in df.columns])
columns_sorted
# Out:
# ['4046',
#  '4225',
#  '4770',
#  'AveragePrice',
#  'Date',
#  'Large Bags',
#  'Small Bags',
#  'Total Bags',
#  'Total Volume',
#  'Unnamed: 0',
#  'XLarge Bags',
#  'new_column',
#  'region',
#  'sentence',
#  'type',
#  'year']

# %%
df[columns_sorted[3:-1]]
# Out:
#        AveragePrice        Date  Large Bags  Small Bags  Total Bags  \
# 0              1.33  2015-12-27       93.25     8603.62     8696.87
# 1              1.35  2015-12-20       97.49     9408.07     9505.56
# 2              0.93  2015-12-13      103.14     8042.21     8145.35
# 3              1.08  2015-12-06      133.76     5677.40     5811.16
# 4              1.28  2015-11-29      197.69     5986.26     6183.95
# ...             ...         ...         ...         ...         ...
# 18244          1.63  2018-02-04      431.85    13066.82    13498.67
# 18245          1.71  2018-01-28      324.80     8940.04     9264.84
# 18246          1.87  2018-01-21       42.31     9351.80     9394.11
# 18247          1.93  2018-01-14       50.00    10919.54    10969.54
# 18248          1.62  2018-01-07       26.01    11988.14    12014.15
#
#        Total Volume  Unnamed: 0  XLarge Bags  new_column            region  \
# 0          64236.62           0          0.0   expensive            Albany
# 1          54876.98           1          0.0   expensive            Albany
# 2         118220.22           2          0.0  affordable            Albany
# 3          78992.15           3          0.0   expensive            Albany
# 4          51039.60           4          0.0   expensive            Albany
# ...             ...         ...          ...         ...               ...
# 18244      17074.83           7          0.0   expensive  WestTexNewMexico
# 18245      13888.04           8          0.0   expensive  WestTexNewMexico
# 18246      13766.76           9          0.0   expensive  WestTexNewMexico
# 18247      16205.22          10          0.0   expensive  WestTexNewMexico
# 18248      17489.58          11          0.0   expensive  WestTexNewMexico
#
#                             sentence                                      type
# 0      This is of type: CONVENTIONAL  This is type: this is type: conventional
# 1      This is of type: CONVENTIONAL  This is type: this is type: conventional
# 2      This is of type: CONVENTIONAL  This is type: this is type: conventional
# 3      This is of type: CONVENTIONAL  This is type: this is type: conventional
# 4      This is of type: CONVENTIONAL  This is type: this is type: conventional
# ...                              ...                                       ...
# 18244       This is of type: ORGANIC       This is type: this is type: organic
# 18245       This is of type: ORGANIC       This is type: this is type: organic
# 18246       This is of type: ORGANIC       This is type: this is type: organic
# 18247       This is of type: ORGANIC       This is type: this is type: organic
# 18248       This is of type: ORGANIC       This is type: this is type: organic
#
# [18249 rows x 12 columns]

# %%
df[["AveragePrice", "new_column"]]
# Out:
#        AveragePrice  new_column
# 0              1.33   expensive
# 1              1.35   expensive
# 2              0.93  affordable
# 3              1.08   expensive
# 4              1.28   expensive
# ...             ...         ...
# 18244          1.63   expensive
# 18245          1.71   expensive
# 18246          1.87   expensive
# 18247          1.93   expensive
# 18248          1.62   expensive
#
# [18249 rows x 2 columns]

# %%
#Modify the names of the dataset

dict_col = {i : i.upper() for i in df.columns}
df[dict_col.keys]
# Out:
# {'Unnamed: 0': 'UNNAMED: 0',
#  'Date': 'DATE',
#  'AveragePrice': 'AVERAGEPRICE',
#  'Total Volume': 'TOTAL VOLUME',
#  '4046': '4046',
#  '4225': '4225',
#  '4770': '4770',
#  'Total Bags': 'TOTAL BAGS',
#  'Small Bags': 'SMALL BAGS',
#  'Large Bags': 'LARGE BAGS',
#  'XLarge Bags': 'XLARGE BAGS',
#  'type': 'TYPE',
#  'year': 'YEAR',
#  'region': 'REGION',
#  'sentence': 'SENTENCE',
#  'new_column': 'NEW_COLUMN'}

# %%
new_dict = {
        'new_column': 'NEW_COLUMN',
        'Unnamed: 0': 'UNNAMED: 0',
         'Date': 'DATE',
         'AveragePrice': 'AVERAGEPRICE',
         'Total Volume': 'TOTAL VOLUME',
         '4046': '4046',
         '4225': '4225',
         '4770': '4770',
         'Total Bags': 'TOTAL BAGS',
         'Small Bags': 'SMALL BAGS',
         'Large Bags': 'LARGE BAGS',
         'XLarge Bags': 'XLARGE BAGS',
         'type': 'TYPE',
         'year': 'YEAR',
         'region': 'REGION',
         'sentence': 'SENTENCE'
}

df[new_dict.keys()].sample()
# Out:
#       new_column  Unnamed: 0        Date  AveragePrice  Total Volume    4046  \
# 14800  expensive           6  2017-11-19          1.62      10393.69  186.36
#
#           4225  4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 14800  4241.25   0.0     5966.08     5612.89      353.19          0.0
#
#                                       type  year   region  \
# 14800  This is type: this is type: organic  2017  Atlanta
#
#                        sentence
# 14800  This is of type: ORGANIC

# %%
# reorder: 
    # 1. Either new_list: subset
    #2: reindex method: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html

# %%
# [if_if_met_item IF CONDITION else else_if_else_met]

# %% [markdown]
# Applies a function along an axis of the DataFrame.
# [Read the docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)

# %% [markdown]
# When I do an apply on a column, even though I use a lambda, I don't put axis because in the case below, what I'm doing is modifying a column, I use lambda to tell the apply that the first argument is a string that comes from outside and the second argument is the dataframe's own record.

# %% [markdown]
# `apply to a df`: watch for axis arg

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region', 'sentence', 'new_column'],
#       dtype='object')

# %%
# Two arguments: two columns: apply to a dr

# new col = mean(4046, 4225, 4770)
df["avg"] = df.apply(lambda row: (row['4046'] + row['4225'] + row['4770']) / 3, axis=1) #more specific, becuase im being more general
#wne applying

# 15646 -> (row["4046"] + row["4225"] + row["4770"]) / 3
# 34747 -> row["4046"]

df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046      4225  \
# 5004          12  2016-10-02          1.52     731993.57  196085.62  421421.2
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 5004  10626.67   103860.08   101544.87     1167.15      1148.06
#
#                                           type  year        region  \
# 5004  This is type: this is type: conventional  2016  SanFrancisco
#
#                            sentence new_column        avg
# 5004  This is of type: CONVENTIONAL  expensive  209377.83

# %%
one_row = dict(df.iloc[5004])
one_row
# Out:
# {'Unnamed: 0': 12,
#  'Date': '2016-10-02',
#  'AveragePrice': 1.52,
#  'Total Volume': 731993.57,
#  '4046': 196085.62,
#  '4225': 421421.2,
#  '4770': 10626.67,
#  'Total Bags': 103860.08,
#  'Small Bags': 101544.87,
#  'Large Bags': 1167.15,
#  'XLarge Bags': 1148.06,
#  'type': 'This is type: this is type: conventional',
#  'year': 2016,
#  'region': 'SanFrancisco',
#  'sentence': 'This is of type: CONVENTIONAL',
#  'new_column': 'expensive',
#  'avg': 209377.83000000005}

# %%
def avge_of_three_keys (dict_):
    return (dict_["4046"] + dict_["4225"] + dict_["4770"])/3

# %%
avge_of_three_keys (one_row)
# Out:
# 209377.83000000005

# %%
df.apply(lambda row: row["4046"], axis="columns")

# %% [markdown]
# `lambda & defined function`

# %%
# Two arguments: I pass & whatever is in the column: function pass through a lambda


df["avg_through_subset"] = df[["4046", "4225", "4770"]].apply(lambda another_row: (another_row['4046'] + another_row['4225'] + another_row['4770']) / 3, axis=1) #more specific, becuase im being more general
df.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046     4225  \
# 15311          40  2017-03-26          0.72      22560.01  631.67  3717.06
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 15311   0.0    18211.28     2514.95    15696.33          0.0
#
#                                       type  year    region  \
# 15311  This is type: this is type: organic  2017  Columbus
#
#                        sentence  new_column          avg        avg_2  \
# 15311  This is of type: ORGANIC  affordable  1449.576667  1449.576667
#
#        avg_through_subset
# 15311         1449.576667

# %%
another_row = {
     '4046': 196085.62,
     '4225': 421421.2,
     '4770': 10626.67
}

# %%
# Q: getting the mean of X given columns

df["avg_2"] = df[["4046", "4225", "4770"]].mean(axis=1)
df.sample()

# %% [markdown]
# `pass two arguments`: one from column, another one from me

# %%
def expired_or_not (year, threshold):
    if int(year) > threshold: 
        return "expired"
    else:
        return "not expired yet"

# %%
# if x > 2017
    # return "After 2017"
# else:
    #return "Before 2017"

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 3509          25  2016-07-03          1.17     336701.66  127175.1  42029.92
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 3509  37960.27   129536.37   113573.12     2084.25      13879.0
#
#                                           type  year   region  \
# 3509  This is type: this is type: conventional  2016  Detroit
#
#                            sentence new_column           avg         avg_2  \
# 3509  This is of type: CONVENTIONAL  expensive  69055.096667  69055.096667
#
#       avg_through_subset
# 3509        69055.096667

# %%
df["expiration"] = df.apply(lambda this_is_a_row: expired_or_not(this_is_a_row["year"], 2015), axis="columns")

# %%
df.sample()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 3687          47  2016-01-31          1.07     240911.84  30150.26  141567.72
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 3687  148.18    69045.68    67727.22     1318.46          0.0
#
#                                           type  year              region  \
# 3687  This is type: this is type: conventional  2016  HarrisburgScranton
#
#                            sentence new_column       avg     avg_2  \
# 3687  This is of type: CONVENTIONAL  expensive  57288.72  57288.72
#
#       avg_through_subset expiration
# 3687            57288.72    expired

# %%
df.expiration.value_counts()
# Out:
# expired            12634
# not expired yet     5615
# Name: expiration, dtype: int64

# %%
# APPLY TAKES SOMETHING
    #IF I DO APPLY TO A SERIES
        # lambda x: x.upper()
        # my_upper_function -> should've been defined with one x argument
        
    # ID I DO APPLY TO A DF:
        # input is a row (given we set axis to 1)
        # I access the value (content of the cell) by calling the row["name of column"]
        
        
    # IF TWO ARGS: df.apply(two args)
        # df.apply(lambda x: x["arg_1"], x["arg_2"])
        # df.apply(lambda x: my_defined_function(x["column"], my_passed_arg_at_that_time)) -> 2016

# %% [markdown]
# ## Deleting the duplicates

# %% [markdown]
# [Read the docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html)

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# `duplicated()`

# %% [markdown]
# `drop_duplicates()`

# %% [markdown]
# `keep`

# %% [markdown]
# ## Null values

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df_titanic.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df_titanic.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %% [markdown]
# #### It is null?
#
# `pd.isna()` == `pd.isnull()`

# %%
df_titanic.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %% [markdown]
# #### Is NOT null?

# %%
df_titanic.notnull().sum()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# #### Sum the null values ​​of each column

# %%
df_titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### delete null values
# There are several ways to do this, we take into account the "how" parameter and of course [the docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html).

# %% [markdown]
# `Dropping missing values where all are missing values`

# %%
df_titanic.shape
# Out:
# (891, 15)

# %% [markdown]
# `Dropping missing values where there's ANY`

# %% [markdown]
# `how`: any

# %% [markdown]
# With "any" (parameter that comes by default so be careful not to put anything) all the records in which there is a NaN in any column are deleted

# %%
df_titanic.dropna(how="any", inplace=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %% [markdown]
# `how`: all

# %%
df_titanic.dropna(how="all", inplace=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# `thresh`: int

# %%
df_titanic.dropna(thresh=4, inplace=False) # Require that many non-NA values. Cannot be combined with how.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# Nans: how many?

    # how: any, all
    # thresh: exclusive with how
    
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna

# %%
a = "dfdf".upper()
a
# Out:
# 'DFDF'

# %%
a.upper()
# Out:
# 'DFDF'

# %%
b = a.upper()

# %% [markdown]
# ### How to fill in the missing data

# %% [markdown]
# How about a little [documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)?

# %% [markdown]
# `fillna`

# %% [markdown]
# ## Export data

# %% [markdown]
# `to_csv`

# %% [markdown]
# `to_json`

# %% [markdown]
# **REMINDER:** `inplace=True` if for method to modify the DF, otherwise you need to save it into a new variable.

# %% [markdown]
# # RECAP
#
# - What is pandas?
#     - library: work with tabular data
#         - Series & DataFrame: pandas Class
#         - `pd.Series`: 1d array
#             - `index`: pd.Series.index
#             - `values`: pd.Series.values
#
#             - creation: pd.Series([1, 2, 4])
#
#         - `pd.DataFrame`: 2d arrays (tables)
#             - each column is a Series
#             - each row can be a dictionary <--> a dict_ can be turned into a row
#             - indexes: for rows and for columns
#
#             - axis: 1 (columns)
#             - axis: 0 (rows)
#              - created/built from
#                  - datatypes
#                     ```python
#                     dictionaries = {
#                          "column A": [cell_A1, cell_A2, cell_A3],
#                          "column A": [cell_B1, cell_B2, cell_B3]
#                          }
#
#                     list_of_dictionaries = [{"column A": cell_A1}, {"column A": cell_A2}]
#                     ```
#
#                  - paths
#                      - read_csv
#                      - read_xlsx
#                  - databases
#                      - read_sql
#                      - #df = mongo.query
#
#          - preview & look at meta-info
#              - `head`, `tail`, `sample()`, `df.info`, `df.describe`, `df.shape`, etc
#              - `df.isna().sum()`, `df.isull().sum()`
#
#          - select
#              - df["column"] / df.column
#              - df[["column1", "column2"]]
#
#          - `df.column.unique()`
#          - `df.column.value_counts()`
#          - df["new column"] = df["previous column"] + modification
#          - `inplace=True`: making sure the changes are affecting the original object insted of just returning the copy
#          - `rename`
#              - df.rename(columns = [], axis=1)
#              - df.columns = [a, b, c]
#          - NaN / missing values / null values -> floats by pandas

# %% [markdown]
# ## Pandas usual methods
# ```python
# df.head() # prints the head, default 5 rows
# df.tail() # set the tail, default 5 rows
# df.describe() # statistical description
# df.info() # df information
# df.columns # show column
# df.index # show index
# df.dtypes # show column data types
# df.plot() # make a plot
# df.hist() # make a histogram
# df.col.value_counts() # counts the unique values ​​of a column
# df.col.unique() # returns unique values ​​from a column
# df.copy() # copies the df
# df.drop() # remove columns or rows (axis=0,1)
# df.dropna() # remove nulls
# df.fillna() # fills nulls
# df.shape # dimensions of the df
# df._get_numeric_data() # select numeric columns
# df.rename() # rename columns
# df.str.replace() # replace columns of strings
# df.astype(dtype='float32') # change the data type
# df.iloc[] # locate by index
# df.loc[] # locate by element
# df.transpose() # transposes the df
# df.T
# df.sample(n, frac) # sample from df
# df.col.sum() # sum of a column
# df.col.max() # maximum of a column
# df.col.min() # minimum of one column
# df[col] # select column
# df.col
# df.isnull() # null values
# df.isna()
# df.notna() # not null values
# df.drop_duplicates() # remove duplicates
# df.reset_index(inplace=True) # reset the index and overwrite
# ```

# %% [markdown]
# ## Further materials
#
# * [Read the docs!](https://pandas.pydata.org/pandas-docs/stable/index.html)
# * [Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Exercises to practice](https://github.com/guipsamora/pandas_exercises)
# * [More on merge, concat, and join](https://realpython.com/pandas-merge-join-and-concat/#pandas-join-combining-data-on-a-column-or-index). And [even more!](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
# * [Categories on df](https://runebook.dev/en/docs/pandas/user_guide/categorical)
