# %% [markdown]
# # Introduction to statistics
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# **Fun fact:** The word statistics comes from the modern Latin *statisticum collegium* (conference on affairs of state), which gave rise to the Italian word *statista* (statesman). or political - compared to the state) and German *Statistik* (originally the analysis of data on the state). At the beginning of the 19th century it acquired the meaning of data collection and classification in general. Data collection on states and localities continues, largely through national and international statistical services. See [reference](https://math.wikia.org/wiki/Statistics#:~:text=The%20word%20statistics%20comes%20from,of%20data%20about%20the%20state).

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Summarize-distributions" data-toc-modified-id="Summarize-distributions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Summarize distributions</a></span><ul class="toc-item"><li><span><a href="#Sample-mean" data-toc-modified-id="Sample-mean-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Sample mean</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Exercise 📝</a></span><ul class="toc-item"><li><span><a href="#Truncated-Mean" data-toc-modified-id="Truncated-Mean-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Truncated Mean</a></span></li><li><span><a href="#Median" data-toc-modified-id="Median-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Median</a></span></li><li><span><a href="#Mode" data-toc-modified-id="Mode-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Mode</a></span></li></ul></li><li><span><a href="#Variance-and-standard-deviation" data-toc-modified-id="Variance-and-standard-deviation-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Variance and standard deviation</a></span></li><li><span><a href="#Asymmetry-(Skewness)" data-toc-modified-id="Asymmetry-(Skewness)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Asymmetry (Skewness)</a></span></li><li><span><a href="#Other-moments-of-distributions" data-toc-modified-id="Other-moments-of-distributions-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Other moments of distributions</a></span></li></ul></li><li><span><a href="#Percentiles-and-boxplots" data-toc-modified-id="Percentiles-and-boxplots-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Percentiles and boxplots</a></span><ul class="toc-item"><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Exercise 📝</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Exercise 📝</a></span></li><li><span><a href="#Outliers-/-Outliers" data-toc-modified-id="Outliers-/-Outliers-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Outliers / Outliers</a></span></li><li><span><a href="#Boxplots-are-very-useful-for-comparing-distributions" data-toc-modified-id="Boxplots-are-very-useful-for-comparing-distributions-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Boxplots are very useful for comparing distributions</a></span></li><li><span><a href="#We-already-saw-the-violinplots,-they-are-not-so-typical-and-there-are-people-who-love-them-and-people-who-hate-them" data-toc-modified-id="We-already-saw-the-violinplots,-they-are-not-so-typical-and-there-are-people-who-love-them-and-people-who-hate-them-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>We already saw the violinplots, they are not so typical and there are people who love them and people who hate them</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Exercise 📝</a></span></li></ul></li><li><span><a href="#Relationships-between-variables" data-toc-modified-id="Relationships-between-variables-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Relationships between variables</a></span><ul class="toc-item"><li><span><a href="#Covariance" data-toc-modified-id="Covariance-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Covariance</a></span></li><li><span><a href="#Pearson-Correlation" data-toc-modified-id="Pearson-Correlation-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Pearson Correlation</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Exercise 📝</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Exercise 📝</a></span></li><li><span><a href="#Spearman-Correlation" data-toc-modified-id="Spearman-Correlation-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Spearman Correlation</a></span></li><li><span><a href="#Exercise-📝" data-toc-modified-id="Exercise-📝-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Exercise 📝</a></span></li><li><span><a href="#Correlation-is-not-causation!!" data-toc-modified-id="Correlation-is-not-causation!!-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Correlation is not causation!!</a></span></li><li><span><a href="#Visualization-of-multiple-relationships" data-toc-modified-id="Visualization-of-multiple-relationships-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Visualization of multiple relationships</a></span><ul class="toc-item"><li><span><a href="#Pairplot" data-toc-modified-id="Pairplot-3.8.1"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>Pairplot</a></span></li><li><span><a href="#Heatmaps" data-toc-modified-id="Heatmaps-3.8.2"><span class="toc-item-num">3.8.2&nbsp;&nbsp;</span>Heatmaps</a></span></li></ul></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#References-&amp;-further-materials" data-toc-modified-id="References-&amp;-further-materials-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>References &amp; further materials</a></span></li></ul></div>

# %%
# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
import numpy as np
import pandas as pd
import random

# %%
# Welcome to SciPy!
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr

# %%
# DISC: barplots/countplots
# NON-DISC: histograms

# %% [markdown]
# ## Summarize distributions
#
# Plotting the histogram of a distribution is always a good idea. It provides a lot of information at a glance. However, sometimes we want to summarize our distributions with a set of representative numbers, also known as `summary statistics`.
#
# **Note:** We call `statistical` any quantity calculated from the values ​​of a sample that is used for statistical purposes. See [Wikipedia](https://en.wikipedia.org/wiki/Statistic).

# %%
df_titanic = sns.load_dataset("titanic")
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.hist("age", bins = np.linspace(0, 80, 9));

# %% [markdown]
# ### Sample mean
#
# [Wikepedia](https://en.wikipedia.org/wiki/Mean): For a data set, the arithmetic mean, also called the expected value or mean, is the central value of a discrete set of numbers: specifically, the sum of the values ​​divided by the number of values.
# $$\bar{x} = \frac{\sum x_i}{N} = \frac{x_1 + x_2 + \dots + x_n}{N}$$

# %%
df_titanic["age"].mean()
# Out:
# 29.69911764705882

# %%
df_titanic.age.mean()
# Out:
# 29.69911764705882

# %%
np.mean(df_titanic["age"])
# Out:
# 29.69911764705882

# %%
df_titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df2 = df_titanic.copy().dropna()

# %%
#df3 = df_titanic.dropna()

# %%
df2.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df_titanic
df_2

# %%
# PLOT WITH MISSING VALUES

graph = sns.histplot(x=df_titanic.age, bins=np.linspace(0, 80, 9))
graph.axvline(df2.age.mean(), 
             c="red",
             label="Mean age without Nan",
             linestyle="--",
             linewidth = 3) # without NaN # {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}

graph.axvline(df_titanic.age.mean(), c="yellow",
             label="Mean age with Nan", #with Nan
            linestyle="--",
             linewidth = 3)

plt.title("Histogram of age on the Titanic")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend();

# %%
# PLOT WITHOUT MISSING VALUES

graph = sns.histplot(x=df2.age, bins=np.linspace(0,80,9))
graph.axvline(df2.age.mean(), 
             c="red",
             label="Mean age without Nan",
             linestyle="--",
             linewidth = 3) # without NaN # {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}

graph.axvline(df_titanic.age.mean(), c="yellow",
             label="Mean age with Nan", #with Nan
            linestyle="--",
             linewidth = 3)

plt.title("Histogram of age on the Titanic")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()

plt.show(); #closing argument for the class

# %% [markdown]
# The mean is by far the most widely used measure of centrality to summarize a distribution. However, it has one main drawback: it is very sensitive to extreme observations (also known as "outliers").
#
# Let us analyze the [wage distribution](https://www.ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736177025&menu=ultiDatos&idp=1254735976596) in Spain to illustrate this. According to INE, the average salary is around 25.165,51 euros. Annual survey 2020. We could think that salaries are distributed something like this:

# %%
sample_mean = 25165
sample_std = 5000
population = 10000

# %%
mock_salaries = np.random.normal(sample_mean, sample_std, population)
mock_salaries
# Out:
# array([20437.50963787, 21916.13484763, 26681.60585743, ...,
#        32307.99024449, 23235.76369908, 28829.21770272])

# %%
mock_salaries[0]
# Out:
# 20437.509637872627

# %%
mock_salaries[1]
# Out:
# 21916.134847626898

# %%
len(mock_salaries)
# Out:
# 10000

# %% [markdown]
# ### Exercise 📝
#
#
# Calculate the total amount of money spent on wages based on the above distribution.

# %%
plt.hist(mock_salaries, bins=15)
plt.axvline(np.mean(mock_salaries),
           c="red",
           linewidth=3,
           linestyle="--",
           label="Mean salary in Spain")

plt.title("Distribution of salaries in Spain")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.legend();

# %% [markdown]
# Okay, but what about people like Messi? According to [this news]((https://www.lavanguardia.com/deportes/fc-barcelona/20190611/462809307977/messi-mejor-pagado-forbes-cristiano-neymar-2019.html)), in 2019 he won about 112 million of euros.

# %%
messi_salary = 112e6

# %%
salaries_with_messi = np.append(mock_salaries, messi_salary)

# %%
plt.hist(mock_salaries, bins=15)
plt.axvline(np.mean(mock_salaries),
           c="red",
           linewidth=3,
           linestyle="--",
           label="Mean salary in Spain")

plt.axvline(np.mean(salaries_with_messi),
           c="yellow",
           linewidth=3,
           linestyle="--",
           label="Mean salary in Spain WITH Messi")


plt.title("Distribution of salaries in Spain")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.legend();

# %%
np.mean(mock_salaries)
# Out:
# 25149.83817603283

# %%
np.mean(salaries_with_messi)
# Out:
# 36346.20355567726

# %% [markdown]
# 🤔

# %% [markdown]
# This new mean doesn't seem very representative of the population, does it? Fortunately, we have a couple of options to improve stats in this scenario.

# %% [markdown]
# #### Truncated Mean
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Truncated_mean) A truncated mean or trimmed mean is a statistical measure of central tendency, much like the mean and median. It involves calculating the mean after discarding certain parts of a probability distribution or sample at the high and low ends, and usually discarding an equal number of both.

# %% [markdown]
# **Truncated mean**

# %%
trim_mean(mock_salaries, 0.01)
# Out:
# 25149.1880078052

# %%
trim_mean(salaries_with_messi, 0.01)
# Out:
# 25150.35897330101

# %%
np.mean(salaries_with_messi)
# Out:
# 36346.20355567726

# %% [markdown]
# #### Median
#
# [Wikipedia](https://en.wikipedia.org/wiki/Median): In statistics and probability theory, the median is a value that separates the upper half from the lower half of a data sample, a population, or a probability distribution. For a data set, it can be thought of as the "middle" value. The basic advantage of the median in describing data over the mean (often simply described as the "average") is that it is not biased as much by a small proportion of extremely large or extremely small values, and therefore can give a better idea of ​​a "typical" value.

# %%
# median tells you the point in the middle
    # left half and right half has the same amount of data points

# %% [markdown]
# ####  Mode
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Mode_(statistics)) The mode is the value that appears most often in a set of data values. Distributions can have more than one mode (or local maxima). These distributions are called *multimodal*.
#
# In the case of discrete variables (or *quasi* discrete) it is a more or less easy quantity to calculate:

# %%
df_titanic.age.mode()
# Out:
# 0    24.0
# dtype: float64

# %%
df_titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
df_titanic[df_titanic["age"] == int(df_titanic.age.mode())]["age"].count()
# Out:
# 30

# %% [markdown]
# But, when the variable is continuous, it most likely won't even have repeating values.
# In that case you should fit your data to a known distribution (or an estimate) and calculate the maximum of the pdf. (See an example [here](https://stackoverflow.com/questions/59662920/how-to-get-the-mode-of-distribution-in-scipy-stats)).

# %%
pd.Series(mock_salaries).plot.kde();

# %%
kernel = gaussian_kde(mock_salaries)
height = kernel.pdf(mock_salaries)
mode_value = mock_salaries[np.argmax(height)]
mode_value
# Out:
# 24959.383368427138

# %%
kernel = gaussian_kde(salaries_with_messi)
height = kernel.pdf(salaries_with_messi)
mode_value = salaries_with_messi[np.argmax(height)]
mode_value
# Out:
# 25149.644305571

# %%
# MEAN
    # sensitive to outliers: Messi: + 120000000
    # this looks at actual value
    # watch out for missing values

# MEDIAN
    # not as sensitive to outliers: Messi: 1+
    # how many values
    # watch out for missing values


# MODE
    # discrete variables
    # continous: mean/median
    # watch out for missing values

# %% [markdown]
# ### Variance and standard deviation
#
# In addition to knowing where a distribution is *centered*, it is also important to know how *variable* the data is, that is, how *spread* it is. Two statistics, the variance and the standard deviation, are useful in this case:
#
# $$Var = \sigma^2 = \frac{\sum (x_i - \mu) ^ 2}{N}$$
#
# $$Std = \sigma = \sqrt{Var}$$
#
# From [Wikipedia:](https://en.wikipedia.org/wiki/Variance) In probability theory and statistics, variance is the expected squared deviation of a random variable from its mean. Informally, it measures the distance of a set of numbers from their mean value.

# %% [markdown]
# (**Note**: The above expressions refer to the Variance of an entire population, where $\mu$ is the population mean. When estimating the Variance or std from a sample, the correct formula is *unbiased* is:
# $$\hat{Var} = \hat\sigma^2 =\frac{\sum (x_i - \bar{x}) ^ 2}{N-1}$$

# %%
#mu, sigma = 0, 0.1 # mean and standard deviation
#s = np.random.normal(mu, sigma, 1000)

# %%
# avg = 25k
# std = 5k

"the distance from the mean"
"mean of the distance between each point and the mean"

# %%
N = 100
# np.random.normal(loc=mean, scale = deviation)

closer_together_distribution = np.random.normal(loc=0, scale = 0.5, size = N)
spread_out_distribution = np.random.normal(loc=0, scale = 2, size = N)


plt.scatter(x = closer_together_distribution, y = np.ones(N), c="black")
plt.scatter( x= spread_out_distribution , y = np.zeros(N), c="y");
plt.scatter( x= spread_out_distribution , y = np.zeros(N), c="y");

# %%
#⚠️: create two ys in a given range so the lines are not flat

# %%
N = 100
plt.hist(np.random.normal(loc=0, scale=0.5, size=N),
        color = "b",
        label = "Low variance",
        alpha = 0.2) # so it's transparent


plt.hist(np.random.normal(0, 2, N),
        color = "orange",
        label="High variance",
        alpha = 0.2) # transparency

plt.legend()
plt.show();

# %%
# On average, how much a point will differ from the mean

# %%
# Variance & std

# Variance: how far points are
    # we square the difference: we wanrt it absolute
# STD: 
    # we square root the variance to get 
    # the same scale

# usually stdeviation is the way to go

# %% [markdown]
# Note that the variance and standard deviations are also very sensitive to outliers:

# %% [markdown]
# ### Asymmetry (Skewness)

# %% [markdown]
# [Wikipedia](https://en.wikipedia.org/wiki/Skewness) In probability theory and statistics, skewness is a measure of the skewness of the probability distribution of a real-valued random variable with respect to his mean. The skewness value can be positive, zero, negative, or undefined.
#
#
# ![image-2.png](attachment:image-2.png)
#
# The relative position of the `mean`, the `median` and the `mode` of the distribution gives us an idea of ​​the `skewness` of our data
#
# ![image.png](attachment:image.png)
#
# The sample skewness is typically calculated as the Fisher-Pearson skewness coefficient. This is the case with the SciPy stats `skew` function. What this coefficient really measures is the difference between the mean and the mode with respect to the dispersion of the set.

# %%
df_titanic.age.hist();

# %%
skew(df_titanic.age.dropna())
# Out:
# 0.3882898514698657

# %%
df2.age.hist();

# %%
skew(df2.age)
# Out:
# 0.018266787174462378

# %%
pd.Series(mock_salaries).hist();

# %%
skew(mock_salaries)
# Out:
# 0.017812327207362533

# %% [markdown]
# **Question:** What will be the sign of the Fisher-Pearson skewness coefficient for the distribution of ages in the Titanic data set?

# %% [markdown]
# ### Other moments of distributions
#
# The mean, variance, and skewness of a distribution are also known as the first, second, and third *[moment](https://en.wikipedia.org/wiki/Central_moment)* respectively. There are others of a higher order, such as the fourth: the *kurtosis*.
#
# All of them give us information about the shape of the distribution. You can watch [this video](https://www.youtube.com/watch?v=ISaVvSO_3Sg) if you are more curious about the moments.

# %% [markdown]
# ![](https://excelrcom.b-cdn.net/assets/admin/ckfinder/userfiles/images/tableau1/tableau2/tableau3/tableau4/tableau5/tableau6/skewness-kurtosis_1JPG-.jpg)

# %%
# moments
    # 1: mean: central tendency
    # 2: variance: spread-out-ness
    # 3: skew: shape on the X axis
    # 4: kurtosis: shape on the Y axis

# %%
centile = 45
"45% of the values fall to the left of that"

centile = 91 
"you did better than 91% of the people"

# %% [markdown]
# ## Percentiles and boxplots
#
# Percentiles (or quantiles) are another useful statistic for understanding distributions. According to [Wikipedia](https://en.wikipedia.org/wiki/Percentile):
#
# "A percentile (or centile) is a measure used in statistics that indicates the value below which a certain percentage of observations in a group of observations falls. For example, the 20th percentile is the value (or score) below the which 20% of the observations can be found. Equivalently, 80% of the observations are above the 20th percentile."
#
# Pandas has the `quantile` method for DataFrame and Series.
#
# See [link](http://web.pdx.edu/~stipakb/download/PA551/boxplot.html) for details and examples.

# %% [markdown]
# quantile = 25, 50, 75
# Q1 = 25 (percentile 25) 25 per cent of my data falls below the value that corresponds to that number
#
#
# percentile 90 -> 70/100, 90% of the students got a lower score than 70

# %% [markdown]
# ### Exercise 📝
# **Conceptual** Can you tell what the relationship is between the median and the quantiles of a distribution?

# %%
# median -> is the centile 50

# %% [markdown]
# ### Exercise 📝
#  Find the age in the titanic data set such that 90% of the passengers were older than that age.

# %%
q1=0.25, q2=0.5, q3=0.75, q4=100

# %%
df_titanic.age.quantile(0.9)
# Out:
# 50.0

# %%
df2.age.quantile(0.9)
# Out:
# 56.0

# %% [markdown]
# A useful representation of a distribution using percentiles is called a `box-plot`.
# ![image.png](attachment:image.png)

# %%
# Out:
# Q1: 20.125
# Q3: 38.0

# %%
print(f"Q1: {df_titanic.age.quantile(0.25)}")
print(f"Q3: {df_titanic.age.quantile(0.75)}")
print(f"Minimumvalue is: {df_titanic.age.min()}")
print(f"Maximum value is: {df_titanic.age.max()}")
# Out:
# Q1: 20.125
# Q3: 38.0
# Minimumvalue is: 0.42
# Maximum value is: 80.0

# %%
sns.boxplot(x="age", data=df_titanic);

# %% [markdown]
# ### Outliers / Outliers
#
# Boxplots typically represent outliers as data points outside the range:
#
# $$\big[ Q_1 - 1.5 * (Q_3 - Q_1 ), Q_3 + 1.5 * (Q_3 - Q_1 ) \big]$$
#
# This is the standard method of deciding if you are an outlier, although outliers are always going to be a problem.
#
# The $(Q_3 - Q_1 ) := IQR$ value is known as the "interquartile range".
#
#
# **Note:** There are other ways to mark observations as outliers, and the $1,5$ value can be changed to any non-negative $k$.
# Depending on the distribution you have, you can calculate it asymmetrically.
# If you don't say anything to the bloxplot, it calculates it for you like this.

# %%
def find_outlier (series):

    outliers = []
    
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    
    iqr = q3 - q1
    
    upper_fence = q3 + 1.5 * iqr
    lower_fence = q1 - 1.5 * iqr
    
    print(f"Lower fence is {lower_fence}")
    print(f"Upper fence is {upper_fence}")
    
    for i in series.values:
        if i < lower_fence or i > upper_fence:
            outliers.append(i)
    
    return sorted(outliers)

# %%
find_outlier (df_titanic.age)
# Out:
# Lower fence is -6.6875
# Upper fence is 64.8125
# [65.0, 65.0, 65.0, 66.0, 70.0, 70.0, 70.5, 71.0, 71.0, 74.0, 80.0]

# %%
sns.boxplot(x="age", data=df2);

# %%
# outliers: messi can be valid
# bad data: negative age

# %%
#find_outlier (pd.Series(mock_salaries))

# %% [markdown]
# ### Boxplots are very useful for comparing distributions

# %% [markdown]
# Questions:
# * Does this plot have evidence on whether more men or more women survived?
# * Among women, do you think that older women survived more? Why do you think this could be?

# %% [markdown]
# ### We already saw the violinplots, they are not so typical and there are people who love them and people who hate them

# %% [markdown]
# ### Exercise 📝
# Create a function that takes an array or a series pd. as input and return outliers. Use it to identify outliers in the `df_titanic.age` series.

# %%
# Reminder of how to get a quantile
        #.quantile(.8)
 # [𝑄1−1.5∗(𝑄3−𝑄1),𝑄3+1.5∗(𝑄3−𝑄1)]

# %% [markdown]
# ## Relationships between variables
#
# The first approach to understanding the relationship between two variables is to plot a scatter plot of one versus the other.

# %%
# are they numeric? -> yes
# correlation
# visually -> heatmap, scatterplot

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = tips, x="total_bill", y="tip");

# %% [markdown]
# There seems to be a clear pattern: The bigger the bill, the bigger the tip. Do we quantify this relationship?

# %% [markdown]
# ### Covariance
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Covariance)
#
# In probability theory and statistics, covariance is a measure of the joint variability of two random variables. If the largest values ​​of one variable correspond mainly to the largest values ​​of the other variable, and the same occurs with the values smaller, (that is, the variables tend to show a similar behavior), the covariance is positive In the opposite case, when the larger values ​​of one variable correspond mainly to the smaller values ​​of the other, (that is, variables tend to show the opposite behavior), the covariance is negative.
# **The sign of the covariance shows, therefore, the trend in the linear relationship between the variables**.
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# The formula for the covariance between two variables ($j$, and $k$) is similar to that for the variance:
#
# $$q_{jk}=\frac{1}{N-1}\sum_{i=1}^{N}\left(  x_{ij}-\bar{x}_j \right)  \left( x_{ik}-\bar{x}_k \right)$$
#
# **Note:** can you see that if $j=k$ the covariance is just the variance?

# %% [markdown]
# **Exercise** 📝 Search the web and find a way in `python` to calculate the covariance of the variables `bill_total` and `tip`.

# %%
tips[["total_bill", "tip"]].cov()
# Out:
#             total_bill       tip
# total_bill   79.252939  8.323502
# tip           8.323502  1.914455

# %% [markdown]
# 79.252939 and 1.914455 is the variance, because it is the covariance with itself. That is, the variance.
# And 8.32 is the covariance between both variables.
#
# The number itself is not telling me anything, because it is a measure that is not normalized. It only allows me to know if it is a positive or negative relationship.

# %%
(100 * tips[["total_bill", "tip"]]).cov()
# Out:
#                total_bill           tip
# total_bill  792529.386140  83235.016292
# tip          83235.016292  19144.546381

# %% [markdown]
# We multiply both columns by 100 imagining that we are doing these calculations in cents. How does this affect the covariance?

# %%
tips[["total_bill", "tip"]].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
(100 * tips[["total_bill", "tip"]]).corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
# COVARIANCE
    # a variable changing along with another one
    # if positive: when one goes up the other one goes up
    # if negative: when one goes up, the other one goes down
    # if close to zero: ? 
    
    # doesn't tell us as much

# CORRELATION
    # -1 and 1
    # HOW MUCH, how big is the strength by which this is changing

# %%
iris = sns.load_dataset("iris")
iris.sample()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 25           5.0          3.0           1.6          0.2  setosa

# %%
#sns.heatmap(tips[["total_bill", "tip"]].corr(), vmin = -1, vmax = 1);

# %%
corr= iris.corr()

# Getting the Upper Triangle of the co-relation matrix
matrix = np.triu(corr)

# using the upper triangle matrix as mask 
sns.heatmap(corr, annot=True, mask=matrix,
           vmin = -1,
           vmax = 1);

# %%
sns.pairplot(iris, hue="species");

# %%
# !open .

# %% [markdown]
# - Quantitative variables: distributions
#
#     - Central tendency (1st moment)
#         - Mean: avg value, very sensitive to outliers
#         - Median: middle point. NOT as sensitive to outliers.
#         - Mode: most frequent value
#
#     - Variance (2nd moment)
#          - Measure of dispersion: how much points differ from the mean
#         - Same mean doesnt mean equal distribution
#         - Std: it gives the same scale of the data
#         - On average, how wrong i'd be guessing one salary knowing the mean
#
#     - Skew (3rd moment): shape: concentration of the values
#         - to the left: tail is to the right: +
#             - everyone was more younger than older
#         - to the right: tail is to the left -
#             - everyone is richer than poorer
#
#
#     relationships between variables
#         - covariance -> correlation: -1 to 1
#
#
#  VISUALLY
#     - boxplots / violinplots
#         - Q1, Q3, min, max & outliers if any
#     - two variables
#          - scatterplot
#         - heatmaps
#     - more than two
#         - pairplots
#         - heatmaps

# %% [markdown]
# ### Pearson Correlation
#
# The magnitude of the covariance is not easy to interpret because it is not normalized and therefore depends on the magnitudes of the variables. However, the normalized version of the covariance, the Pearson correlation coefficient, shows by its magnitude the strength of the linear relationship. The formula is
#
# $$\rho_{X,Y} = \frac{Cov(X,Y)}{\sigma_X \sigma_Y}$$
#
#
# where $\sigma_X$ and $\sigma_Y$ are the respective standard deviations.
#
# Pearson's correlation coefficient is a statistic that measures the linear correlation between two variables X and Y. It has a value between +1 and -1. A value of +1 is full positive linear correlation, 0 is no linear correlation, and -1 is full negative linear correlation.
#
#
# **WARNING!** The fact that the correlation (or covariance) is zero does not mean that there are no patterns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 📝
# Search the web and find a `python` way to calculate the Pearson correlation between the variables `total_billing` and `tip`.

# %% [markdown]
# ### Exercise 📝
# Now multiply both columns by 100. Recalculate the correlation. It affects?

# %% [markdown]
# ### Spearman Correlation
# Pearson's correlation suffers greatly from outliers.
# Pearson's correlation is the *standard* correlation, and it works well when the relationship between variables is strictly linear and normally distributed. However, it has one main drawback:

# %% [markdown]
# ### Exercise 📝
# Sensitivity to outliers
#
# Imagine that Messi went to the restaurant where the tip data set was collected. He ate for 100 and was so happy that he left a $1,000 tip.
#
# * Add this observation to a new copy of the dataset
# * Plot the scatterplot again
# * How does this new observation affect the correlation between both variables?

# %%
# Your code here

# %% [markdown]
# An alternative correlation coefficient known as [Spearman's correlation coefficient](https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient) solves this problem by computing Pearson's correlation for the ranks . The sign of the Spearman correlation indicates the direction of the association between X (the independent variable) and Y (the dependent variable). If Y tends to increase as X increases, Spearman's correlation coefficient is positive. If Y tends to decrease as X increases, Spearman's correlation coefficient is negative. A Spearman correlation of zero indicates that there is no tendency for Y to increase or decrease as X increases. Spearman's correlation increases in magnitude as X and Y get closer to being perfectly monotone functions of each other. When X and Y are perfectly monotonically related, the Spearman correlation coefficient becomes 1.
#
# For more information, see [this post](https://towardsdatascience.com/clearly-explained-pearson-v-s-spearman-correlation-coefficient-ada2f473b8) in towardsdatascience.

# %%
# Pearson
    # Only linear
    # More sensitive to outliers

# Spearman
    # Not as sensitive to outlierst
    
    
# PEARSON -> ONLY LINEAR (first one)

# %% [markdown]
# ![Screenshot%202022-11-02%20at%2012.36.08.png](attachment:Screenshot%202022-11-02%20at%2012.36.08.png)

# %%
# Pearson: won't account for non-linear relations

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# [](data:image/png;base64,...)

# %% [markdown]
# Here we know that the larger one, the larger the other, not necessarily linear and not sensitive to outliers.

# %% [markdown]
# ### Correlation is not causation!!
#
# There are many funny examples around this idea. See for example [this video](https://www.youtube.com/watch?v=8B271L3NtAw). Understanding the difference between correlation and causation is an essential skill for any data analyst!!

# %% [markdown]
# ### Visualization of multiple relationships

# %% [markdown]
# #### Pairplot

# %% [markdown]
# #### Heatmaps

# %% [markdown]
# ## Summary
# It's your turn. What have we learned today?

# %% [markdown]
# ## References & further materials

# %% [markdown]
# * [Think Stats](https://greenteapress.com/wp/think-stats-2e/)
# * [Practical Statistics for Data Scientists](https://www.oreilly.com/library/view/practical-statistics-for/9781491952955/)
