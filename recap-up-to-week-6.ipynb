# %% [markdown]
# **BASH**
# - Scripting
# - Git
#
#
# **GIT**: version control system
# - Clone
# - Git pull and git push
# - Create pull requests
# - Fork
#
#
# **PYTHON**
#
# error hanndling
# map, filter, reduce
# flow control: while, for, break, pass, etc
#
# pandas
# numpy
#
# functional programming
# oop
#
#
# **EXTRACTION**
#
# - API
#     - Read the docs
#     - TOKENS: load_dotenv(), getpass()
#
# - Scrapping
#     - Understand how HTML works
#     - Extract the info
#
#
#
#
# **SQL**
# - CRUD: create, read, update and delete
# - Create temporary tables
# - Create views
# - Procedures (advance)
# - Subqueries
# - SQlAlchemy
#
#
# **MONGODB**
# - CRUD: create, read, update and delete
# - geoqueries
#     - geojson
#
# - queries: documents
# - pymongo
#
#
# **VISUALIZATION**
#
# matpotlib
# seaborn
# plotly(?)
#
# maps: folium, carto
#
# **PROB & STATS**
# Descriptive statistcs: understanding distributions: central tendency measures
# Measures of dispersion
# Probability distributions
# Hypothesis testing
#
#
#
# **MODULARIZATION**
#
#
# - Katas: tolerance frustration
# - Presentation skills: katas & projects

# %% [markdown]
# **DATA ANALYST: ETL & EDA**
#
# - EDA: Exploratory data analysis
# - ETL: Extraction - Transformation - Loading
#
# Python, SQL and noSQL, Visualization

# %% [markdown]
# **DATA SCIENTIST**
#    - math
#    -  machine learning modeling
#
#
# **DATA ANALYST**
#     - Extraction & visualization
#     - Business analyst
#     - Stakeholders 100%
#
#
# **DATA ENGINEER: pipeline**
#    - Salesforce
#    - MongoDB
#     - Google sheets
#
#     - SQL database in a warehouse
#
#
#     - Extraction, Transformation and Loading
#
#
# * Extra: cloud services

# %% [markdown]
# ![image.png](attachment:image.png)
